# %%
import time
from curl_cffi import requests as cureq
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd

# %%
headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36"}

# %%
#First check for the number of houses and pages to be scraped
url = f"https://www.immoweb.be/nl/search-results/huis/te-koop?countries=BE&page=1&orderBy=relevance"

resp = cureq.get(url, headers=headers, impersonate="chrome")

print(resp.status_code)

data = resp.json()

total_houses_1_page = int(data['range'].split('-')[1])

total_number_of_houses= data['totalItems']

number_of_pages = total_number_of_houses//(total_houses_1_page + 1)

print(f'Immoweb contains {total_number_of_houses} listings on {number_of_pages} pages')
# Out:
# 200
# Immoweb contains 9969 listings on 332 pages

# %%
#FIRST SCRAPE: Scrape function

def collect_data(pages: int, headers: dict):
    """
    This function collects data from the specified number of pages and returns a list.

    Args:
    pages (int): Number of pages to collect data from.
    headers (dict): HTTP headers to include in the requests.
    """
    if not headers:
        raise ValueError("Headers are required to make the request.")

    data_collection = []

    # Start the timer
    start_time = time.perf_counter()
    print(f"Start scraping {pages} pages...")

    # Loop through the pages and collect data
    for page in range(1, pages + 1):
        url = f"https://www.immoweb.be/nl/search-results/huis/te-koop?countries=BE&page={page}&orderBy=relevance"
        
        try:
            # Send the request
            print(f"Scraping page {page}...")
            resp = cureq.get(url, headers=headers, impersonate="chrome")
            resp.raise_for_status()  # Raise an error for bad responses (4xx or 5xx)

            # Try to parse the JSON response
            data = resp.json()
            data_collection.append(data)
            print(f"Page {page} scraped successfully.")
        
        except requests.exceptions.RequestException as req_err:
            # Handle network-related errors
            print(f"Network error on page {page}: {req_err}")
        except ValueError:
            # Handle JSON decoding errors
            print(f"Error decoding JSON on page {page}.")
        except Exception as e:
            # Catch any other exceptions
            print(f"An error occurred on page {page}: {e}")

    # Stop the timer and print the elapsed time
    end_time = time.perf_counter()
    elapsed_time = end_time - start_time
    print(f"Data scraping completed in {elapsed_time:.2f} seconds.")

    return data_collection

# %%
#FIRST SCRAPE: Parse function

def parse_data(listings: list):
    """
    Parses the listings data to extract relevant property details.

    Args:
    listings (list): List of raw listings data.

    Returns:
    all_properties (list): List of dictionaries with parsed property data.
    """
    all_properties = []

    for listing in listings:
        # Get the results list (default to an empty list if not found)
        results_list = listing.get('results', [])

        for result in results_list:
            # Extract property details using nested get() for safety
            property_details = result.get('property', {})
            location = property_details.get('location', {})
            transaction = result.get('transaction', {}).get('sale', {})

            property_data = {
                'id': result.get('id'),
                'type': property_details.get('type'),
                'subtype': property_details.get('subtype'),
                'country': location.get('country'),
                'region': location.get('region'),
                'locality_name': location.get('locality'),
                'locality_code': location.get('postalCode'),
                'street': location.get('street'),
                'number': location.get('number'),
                'latitude': location.get('latitude'),
                'longitude': location.get('longitude'),
                'bedroom_count': property_details.get('bedroomCount', "None"),
                'net_habitable_surface': property_details.get('netHabitableSurface'),
                'land_surface': property_details.get('landSurface'),
                'room_count': property_details.get('roomCount', "None"),
                'transaction_type': result.get('transaction', {}).get('type'),
                'sale_annuity': transaction.get('lifeAnnuity'),
                'price': transaction.get('price'),
                'old_price': transaction.get('oldPrice')
            }

            all_properties.append(property_data)

    print(f"Extracted {len(all_properties)} properties from data.")
    return all_properties

# %%
#Testing and starting the first scrape with the scrape function

listings = collect_data(number_of_pages, headers)
# Out:
# Start scraping 332 pages...
# Scraping page 1...
# Page 1 scraped successfully.
# Scraping page 2...
# Page 2 scraped successfully.
# Scraping page 3...
# Page 3 scraped successfully.
# Scraping page 4...
# Page 4 scraped successfully.
# Scraping page 5...
# Page 5 scraped successfully.
# Scraping page 6...
# Page 6 scraped successfully.
# Scraping page 7...
# Page 7 scraped successfully.
# Scraping page 8...
# Page 8 scraped successfully.
# Scraping page 9...
# Page 9 scraped successfully.
# Scraping page 10...
# Page 10 scraped successfully.
# Scraping page 11...
# Page 11 scraped successfully.
# Scraping page 12...
# Page 12 scraped successfully.
# Scraping page 13...
# Page 13 scraped successfully.
# Scraping page 14...
# Page 14 scraped successfully.
# Scraping page 15...
# Page 15 scraped successfully.
# Scraping page 16...
# Page 16 scraped successfully.
# Scraping page 17...
# Page 17 scraped successfully.
# Scraping page 18...
# Page 18 scraped successfully.
# Scraping page 19...
# Page 19 scraped successfully.
# Scraping page 20...
# Page 20 scraped successfully.
# Scraping page 21...
# Page 21 scraped successfully.
# Scraping page 22...
# Page 22 scraped successfully.
# Scraping page 23...
# Page 23 scraped successfully.
# Scraping page 24...
# Page 24 scraped successfully.
# Scraping page 25...
# Page 25 scraped successfully.
# Scraping page 26...
# Page 26 scraped successfully.
# Scraping page 27...
# Page 27 scraped successfully.
# Scraping page 28...
# Page 28 scraped successfully.
# Scraping page 29...
# Page 29 scraped successfully.
# Scraping page 30...
# Page 30 scraped successfully.
# Scraping page 31...
# Page 31 scraped successfully.
# Scraping page 32...
# Page 32 scraped successfully.
# Scraping page 33...
# Page 33 scraped successfully.
# Scraping page 34...
# Page 34 scraped successfully.
# Scraping page 35...
# Page 35 scraped successfully.
# Scraping page 36...
# Page 36 scraped successfully.
# Scraping page 37...
# Page 37 scraped successfully.
# Scraping page 38...
# Page 38 scraped successfully.
# Scraping page 39...
# Page 39 scraped successfully.
# Scraping page 40...
# Page 40 scraped successfully.
# Scraping page 41...
# Page 41 scraped successfully.
# Scraping page 42...
# Page 42 scraped successfully.
# Scraping page 43...
# Page 43 scraped successfully.
# Scraping page 44...
# Page 44 scraped successfully.
# Scraping page 45...
# Page 45 scraped successfully.
# Scraping page 46...
# Page 46 scraped successfully.
# Scraping page 47...
# Page 47 scraped successfully.
# Scraping page 48...
# Page 48 scraped successfully.
# Scraping page 49...
# Page 49 scraped successfully.
# Scraping page 50...
# Page 50 scraped successfully.
# Scraping page 51...
# Page 51 scraped successfully.
# Scraping page 52...
# Page 52 scraped successfully.
# Scraping page 53...
# Page 53 scraped successfully.
# Scraping page 54...
# Page 54 scraped successfully.
# Scraping page 55...
# Page 55 scraped successfully.
# Scraping page 56...
# Page 56 scraped successfully.
# Scraping page 57...
# Page 57 scraped successfully.
# Scraping page 58...
# Page 58 scraped successfully.
# Scraping page 59...
# Page 59 scraped successfully.
# Scraping page 60...
# Page 60 scraped successfully.
# Scraping page 61...
# Page 61 scraped successfully.
# Scraping page 62...
# Page 62 scraped successfully.
# Scraping page 63...
# Page 63 scraped successfully.
# Scraping page 64...
# Page 64 scraped successfully.
# Scraping page 65...
# Page 65 scraped successfully.
# Scraping page 66...
# Page 66 scraped successfully.
# Scraping page 67...
# Page 67 scraped successfully.
# Scraping page 68...
# Page 68 scraped successfully.
# Scraping page 69...
# Page 69 scraped successfully.
# Scraping page 70...
# Page 70 scraped successfully.
# Scraping page 71...
# Page 71 scraped successfully.
# Scraping page 72...
# Page 72 scraped successfully.
# Scraping page 73...
# Page 73 scraped successfully.
# Scraping page 74...
# Page 74 scraped successfully.
# Scraping page 75...
# Page 75 scraped successfully.
# Scraping page 76...
# Page 76 scraped successfully.
# Scraping page 77...
# Page 77 scraped successfully.
# Scraping page 78...
# Page 78 scraped successfully.
# Scraping page 79...
# Page 79 scraped successfully.
# Scraping page 80...
# Page 80 scraped successfully.
# Scraping page 81...
# Page 81 scraped successfully.
# Scraping page 82...
# Page 82 scraped successfully.
# Scraping page 83...
# Page 83 scraped successfully.
# Scraping page 84...
# Page 84 scraped successfully.
# Scraping page 85...
# Page 85 scraped successfully.
# Scraping page 86...
# Page 86 scraped successfully.
# Scraping page 87...
# Page 87 scraped successfully.
# Scraping page 88...
# Page 88 scraped successfully.
# Scraping page 89...
# Page 89 scraped successfully.
# Scraping page 90...
# Page 90 scraped successfully.
# Scraping page 91...
# Page 91 scraped successfully.
# Scraping page 92...
# Page 92 scraped successfully.
# Scraping page 93...
# Page 93 scraped successfully.
# Scraping page 94...
# Page 94 scraped successfully.
# Scraping page 95...
# Page 95 scraped successfully.
# Scraping page 96...
# Page 96 scraped successfully.
# Scraping page 97...
# Page 97 scraped successfully.
# Scraping page 98...
# Page 98 scraped successfully.
# Scraping page 99...
# Page 99 scraped successfully.
# Scraping page 100...
# Page 100 scraped successfully.
# Scraping page 101...
# Page 101 scraped successfully.
# Scraping page 102...
# Page 102 scraped successfully.
# Scraping page 103...
# Page 103 scraped successfully.
# Scraping page 104...
# Page 104 scraped successfully.
# Scraping page 105...
# Page 105 scraped successfully.
# Scraping page 106...
# Page 106 scraped successfully.
# Scraping page 107...
# Page 107 scraped successfully.
# Scraping page 108...
# Page 108 scraped successfully.
# Scraping page 109...
# Page 109 scraped successfully.
# Scraping page 110...
# Page 110 scraped successfully.
# Scraping page 111...
# Page 111 scraped successfully.
# Scraping page 112...
# Page 112 scraped successfully.
# Scraping page 113...
# Page 113 scraped successfully.
# Scraping page 114...
# Page 114 scraped successfully.
# Scraping page 115...
# Page 115 scraped successfully.
# Scraping page 116...
# Page 116 scraped successfully.
# Scraping page 117...
# Page 117 scraped successfully.
# Scraping page 118...
# Page 118 scraped successfully.
# Scraping page 119...
# Page 119 scraped successfully.
# Scraping page 120...
# Page 120 scraped successfully.
# Scraping page 121...
# Page 121 scraped successfully.
# Scraping page 122...
# Page 122 scraped successfully.
# Scraping page 123...
# Page 123 scraped successfully.
# Scraping page 124...
# Page 124 scraped successfully.
# Scraping page 125...
# Page 125 scraped successfully.
# Scraping page 126...
# Page 126 scraped successfully.
# Scraping page 127...
# Page 127 scraped successfully.
# Scraping page 128...
# Page 128 scraped successfully.
# Scraping page 129...
# Page 129 scraped successfully.
# Scraping page 130...
# Page 130 scraped successfully.
# Scraping page 131...
# Page 131 scraped successfully.
# Scraping page 132...
# Page 132 scraped successfully.
# Scraping page 133...
# Page 133 scraped successfully.
# Scraping page 134...
# Page 134 scraped successfully.
# Scraping page 135...
# Page 135 scraped successfully.
# Scraping page 136...
# Page 136 scraped successfully.
# Scraping page 137...
# Page 137 scraped successfully.
# Scraping page 138...
# Page 138 scraped successfully.
# Scraping page 139...
# Page 139 scraped successfully.
# Scraping page 140...
# Page 140 scraped successfully.
# Scraping page 141...
# Page 141 scraped successfully.
# Scraping page 142...
# Page 142 scraped successfully.
# Scraping page 143...
# Page 143 scraped successfully.
# Scraping page 144...
# Page 144 scraped successfully.
# Scraping page 145...
# Page 145 scraped successfully.
# Scraping page 146...
# Page 146 scraped successfully.
# Scraping page 147...
# Page 147 scraped successfully.
# Scraping page 148...
# Page 148 scraped successfully.
# Scraping page 149...
# Page 149 scraped successfully.
# Scraping page 150...
# Page 150 scraped successfully.
# Scraping page 151...
# Page 151 scraped successfully.
# Scraping page 152...
# Page 152 scraped successfully.
# Scraping page 153...
# Page 153 scraped successfully.
# Scraping page 154...
# Page 154 scraped successfully.
# Scraping page 155...
# Page 155 scraped successfully.
# Scraping page 156...
# Page 156 scraped successfully.
# Scraping page 157...
# Page 157 scraped successfully.
# Scraping page 158...
# Page 158 scraped successfully.
# Scraping page 159...
# Page 159 scraped successfully.
# Scraping page 160...
# Page 160 scraped successfully.
# Scraping page 161...
# Page 161 scraped successfully.
# Scraping page 162...
# Page 162 scraped successfully.
# Scraping page 163...
# Page 163 scraped successfully.
# Scraping page 164...
# Page 164 scraped successfully.
# Scraping page 165...
# Page 165 scraped successfully.
# Scraping page 166...
# Page 166 scraped successfully.
# Scraping page 167...
# Page 167 scraped successfully.
# Scraping page 168...
# Page 168 scraped successfully.
# Scraping page 169...
# Page 169 scraped successfully.
# Scraping page 170...
# Page 170 scraped successfully.
# Scraping page 171...
# Page 171 scraped successfully.
# Scraping page 172...
# Page 172 scraped successfully.
# Scraping page 173...
# Page 173 scraped successfully.
# Scraping page 174...
# Page 174 scraped successfully.
# Scraping page 175...
# Page 175 scraped successfully.
# Scraping page 176...
# Page 176 scraped successfully.
# Scraping page 177...
# Page 177 scraped successfully.
# Scraping page 178...
# Page 178 scraped successfully.
# Scraping page 179...
# Page 179 scraped successfully.
# Scraping page 180...
# Page 180 scraped successfully.
# Scraping page 181...
# Page 181 scraped successfully.
# Scraping page 182...
# Page 182 scraped successfully.
# Scraping page 183...
# Page 183 scraped successfully.
# Scraping page 184...
# Page 184 scraped successfully.
# Scraping page 185...
# Page 185 scraped successfully.
# Scraping page 186...
# Page 186 scraped successfully.
# Scraping page 187...
# Page 187 scraped successfully.
# Scraping page 188...
# Page 188 scraped successfully.
# Scraping page 189...
# Page 189 scraped successfully.
# Scraping page 190...
# Page 190 scraped successfully.
# Scraping page 191...
# Page 191 scraped successfully.
# Scraping page 192...
# Page 192 scraped successfully.
# Scraping page 193...
# Page 193 scraped successfully.
# Scraping page 194...
# Page 194 scraped successfully.
# Scraping page 195...
# Page 195 scraped successfully.
# Scraping page 196...
# Page 196 scraped successfully.
# Scraping page 197...
# Page 197 scraped successfully.
# Scraping page 198...
# Page 198 scraped successfully.
# Scraping page 199...
# Page 199 scraped successfully.
# Scraping page 200...
# Page 200 scraped successfully.
# Scraping page 201...
# Page 201 scraped successfully.
# Scraping page 202...
# Page 202 scraped successfully.
# Scraping page 203...
# Page 203 scraped successfully.
# Scraping page 204...
# Page 204 scraped successfully.
# Scraping page 205...
# Page 205 scraped successfully.
# Scraping page 206...
# Page 206 scraped successfully.
# Scraping page 207...
# Page 207 scraped successfully.
# Scraping page 208...
# Page 208 scraped successfully.
# Scraping page 209...
# Page 209 scraped successfully.
# Scraping page 210...
# Page 210 scraped successfully.
# Scraping page 211...
# Page 211 scraped successfully.
# Scraping page 212...
# Page 212 scraped successfully.
# Scraping page 213...
# Page 213 scraped successfully.
# Scraping page 214...
# Page 214 scraped successfully.
# Scraping page 215...
# Page 215 scraped successfully.
# Scraping page 216...
# Page 216 scraped successfully.
# Scraping page 217...
# Page 217 scraped successfully.
# Scraping page 218...
# Page 218 scraped successfully.
# Scraping page 219...
# Page 219 scraped successfully.
# Scraping page 220...
# Page 220 scraped successfully.
# Scraping page 221...
# Page 221 scraped successfully.
# Scraping page 222...
# Page 222 scraped successfully.
# Scraping page 223...
# Page 223 scraped successfully.
# Scraping page 224...
# Page 224 scraped successfully.
# Scraping page 225...
# Page 225 scraped successfully.
# Scraping page 226...
# Page 226 scraped successfully.
# Scraping page 227...
# Page 227 scraped successfully.
# Scraping page 228...
# Page 228 scraped successfully.
# Scraping page 229...
# Page 229 scraped successfully.
# Scraping page 230...
# Page 230 scraped successfully.
# Scraping page 231...
# Page 231 scraped successfully.
# Scraping page 232...
# Page 232 scraped successfully.
# Scraping page 233...
# Page 233 scraped successfully.
# Scraping page 234...
# Page 234 scraped successfully.
# Scraping page 235...
# Page 235 scraped successfully.
# Scraping page 236...
# Page 236 scraped successfully.
# Scraping page 237...
# Page 237 scraped successfully.
# Scraping page 238...
# Page 238 scraped successfully.
# Scraping page 239...
# Page 239 scraped successfully.
# Scraping page 240...
# Page 240 scraped successfully.
# Scraping page 241...
# Page 241 scraped successfully.
# Scraping page 242...
# Page 242 scraped successfully.
# Scraping page 243...
# Page 243 scraped successfully.
# Scraping page 244...
# Page 244 scraped successfully.
# Scraping page 245...
# Page 245 scraped successfully.
# Scraping page 246...
# Page 246 scraped successfully.
# Scraping page 247...
# Page 247 scraped successfully.
# Scraping page 248...
# Page 248 scraped successfully.
# Scraping page 249...
# Page 249 scraped successfully.
# Scraping page 250...
# Page 250 scraped successfully.
# Scraping page 251...
# Page 251 scraped successfully.
# Scraping page 252...
# Page 252 scraped successfully.
# Scraping page 253...
# Page 253 scraped successfully.
# Scraping page 254...
# Page 254 scraped successfully.
# Scraping page 255...
# Page 255 scraped successfully.
# Scraping page 256...
# Page 256 scraped successfully.
# Scraping page 257...
# Page 257 scraped successfully.
# Scraping page 258...
# Page 258 scraped successfully.
# Scraping page 259...
# Page 259 scraped successfully.
# Scraping page 260...
# Page 260 scraped successfully.
# Scraping page 261...
# Page 261 scraped successfully.
# Scraping page 262...
# Page 262 scraped successfully.
# Scraping page 263...
# Page 263 scraped successfully.
# Scraping page 264...
# Page 264 scraped successfully.
# Scraping page 265...
# Page 265 scraped successfully.
# Scraping page 266...
# Page 266 scraped successfully.
# Scraping page 267...
# Page 267 scraped successfully.
# Scraping page 268...
# Page 268 scraped successfully.
# Scraping page 269...
# Page 269 scraped successfully.
# Scraping page 270...
# Page 270 scraped successfully.
# Scraping page 271...
# Page 271 scraped successfully.
# Scraping page 272...
# Page 272 scraped successfully.
# Scraping page 273...
# Page 273 scraped successfully.
# Scraping page 274...
# Page 274 scraped successfully.
# Scraping page 275...
# Page 275 scraped successfully.
# Scraping page 276...
# Page 276 scraped successfully.
# Scraping page 277...
# Page 277 scraped successfully.
# Scraping page 278...
# Page 278 scraped successfully.
# Scraping page 279...
# Page 279 scraped successfully.
# Scraping page 280...
# Page 280 scraped successfully.
# Scraping page 281...
# Page 281 scraped successfully.
# Scraping page 282...
# Page 282 scraped successfully.
# Scraping page 283...
# Page 283 scraped successfully.
# Scraping page 284...
# Page 284 scraped successfully.
# Scraping page 285...
# Page 285 scraped successfully.
# Scraping page 286...
# Page 286 scraped successfully.
# Scraping page 287...
# Page 287 scraped successfully.
# Scraping page 288...
# Page 288 scraped successfully.
# Scraping page 289...
# Page 289 scraped successfully.
# Scraping page 290...
# Page 290 scraped successfully.
# Scraping page 291...
# Page 291 scraped successfully.
# Scraping page 292...
# Page 292 scraped successfully.
# Scraping page 293...
# Page 293 scraped successfully.
# Scraping page 294...
# Page 294 scraped successfully.
# Scraping page 295...
# Page 295 scraped successfully.
# Scraping page 296...
# Page 296 scraped successfully.
# Scraping page 297...
# An error occurred on page 297: HTTP Error 500:
# Scraping page 298...
# Page 298 scraped successfully.
# Scraping page 299...
# Page 299 scraped successfully.
# Scraping page 300...
# Page 300 scraped successfully.
# Scraping page 301...
# Page 301 scraped successfully.
# Scraping page 302...
# Page 302 scraped successfully.
# Scraping page 303...
# Page 303 scraped successfully.
# Scraping page 304...
# Page 304 scraped successfully.
# Scraping page 305...
# Page 305 scraped successfully.
# Scraping page 306...
# Page 306 scraped successfully.
# Scraping page 307...
# Page 307 scraped successfully.
# Scraping page 308...
# Page 308 scraped successfully.
# Scraping page 309...
# Page 309 scraped successfully.
# Scraping page 310...
# Page 310 scraped successfully.
# Scraping page 311...
# Page 311 scraped successfully.
# Scraping page 312...
# Page 312 scraped successfully.
# Scraping page 313...
# Page 313 scraped successfully.
# Scraping page 314...
# Page 314 scraped successfully.
# Scraping page 315...
# Page 315 scraped successfully.
# Scraping page 316...
# Page 316 scraped successfully.
# Scraping page 317...
# Page 317 scraped successfully.
# Scraping page 318...
# Page 318 scraped successfully.
# Scraping page 319...
# Page 319 scraped successfully.
# Scraping page 320...
# Page 320 scraped successfully.
# Scraping page 321...
# Page 321 scraped successfully.
# Scraping page 322...
# Page 322 scraped successfully.
# Scraping page 323...
# Page 323 scraped successfully.
# Scraping page 324...
# Page 324 scraped successfully.
# Scraping page 325...
# Page 325 scraped successfully.
# Scraping page 326...
# Page 326 scraped successfully.
# Scraping page 327...
# Page 327 scraped successfully.
# Scraping page 328...
# Page 328 scraped successfully.
# Scraping page 329...
# Page 329 scraped successfully.
# Scraping page 330...
# Page 330 scraped successfully.
# Scraping page 331...
# Page 331 scraped successfully.
# Scraping page 332...
# Page 332 scraped successfully.
# Data scraping completed in 358.86 seconds.

# %%
#Here i create a json file with one element of listings so we can have a look of the json data from one listing on the overview pages that was scraped during the first scrape
with open('listings_first_scrape_test.json', 'w') as f:
    json.dump(listings[0], f, indent=4)

# %%
#Parse all the data from the first scrape and put it in a list

all_properties = parse_data(listings)
# Out:
# Extracted 9930 properties from data.

# %%
#An overview of the data that was kept from one listing

all_properties[18]
# Out:
# {'id': 20257810,
#  'type': 'HOUSE',
#  'subtype': 'EXCEPTIONAL_PROPERTY',
#  'country': 'België',
#  'region': 'Wallonië',
#  'locality_name': 'Libin (Transinne)',
#  'locality_code': '6890',
#  'street': "Rue de l'Eglise",
#  'number': '2',
#  'latitude': 50.0000839,
#  'longitude': 5.203685699999999,
#  'bedroom_count': 2,
#  'net_habitable_surface': 232,
#  'land_surface': 969,
#  'room_count': None,
#  'transaction_type': 'FOR_SALE',
#  'sale_annuity': None,
#  'price': 349000,
#  'old_price': None}

# %%
#create a first listings list 

listings_1 = []  

for house in all_properties:
    listing_1 = {}  
    listing_1['id'] = house.get('id')
    listing_1['locality_name'] = house.get('locality_name')
    listing_1['Postal_code'] = house.get('locality_code')
    listing_1['Price'] = house.get('price')
    listing_1['Subtype'] = house.get('subtype')
    listing_1['Number_of_rooms'] = house.get('room_count')
    listing_1['Number_of_bedrooms'] = house.get('bedroom_count')
    listing_1['Living_area'] = house.get('net_habitable_surface')
    listing_1['sale_annuity'] = house.get('sale_annuity')
    listing_1['Type_of_sale'] = house.get('transaction_type')
    listing_1['street'] = house.get('street')
    listing_1['number'] = house.get('number')
    listing_1['latitude'] = house.get('latitude')
    listing_1['longitude'] = house.get('longitude')
    listing_1['landSurface'] = house.get('land_surface')
    
    
    listings_1.append(listing_1)  

listings_1
# Out:
# [{'id': 20264804,
#   'locality_name': 'Wetteren',
#   'Postal_code': '9230',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Cooppallaan',
#   'number': '30',
#   'latitude': 51.009508,
#   'longitude': 3.876983,
#   'landSurface': None},
#  {'id': 20260393,
#   'locality_name': 'Schaerbeek',
#   'Postal_code': '1030',
#   'Price': 495000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 3,
#   'Living_area': 120,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue Joseph Wauters',
#   'number': '77',
#   'latitude': 50.8689682,
#   'longitude': 4.3946084,
#   'landSurface': 100},
#  {'id': 20260850,
#   'locality_name': 'Woluwe-Saint-Pierre',
#   'Postal_code': '1150',
#   'Price': 575000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 5,
#   'Living_area': 177,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue du Duc',
#   'number': '72',
#   'latitude': 50.83773900000001,
#   'longitude': 4.412516399999999,
#   'landSurface': 137},
#  {'id': 20254029,
#   'locality_name': 'SINT-PIETERS-LEEUW',
#   'Postal_code': '1600',
#   'Price': 449000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 2,
#   'Living_area': 121,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Tuinwijk Zuun',
#   'number': '18',
#   'latitude': 50.7811095,
#   'longitude': 4.275871299999999,
#   'landSurface': 293},
#  {'id': 20262954,
#   'locality_name': 'Geraardsbergen Ophasselt',
#   'Postal_code': '9500',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Doornkouter',
#   'number': None,
#   'latitude': 50.8131022,
#   'longitude': 3.876165,
#   'landSurface': None},
#  {'id': 20264095,
#   'locality_name': 'Oostnieuwkerke',
#   'Postal_code': '8840',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Veldstraat',
#   'number': '29',
#   'latitude': 50.9318666,
#   'longitude': 3.0373681,
#   'landSurface': None},
#  {'id': 20264349,
#   'locality_name': 'HARELBEKE',
#   'Postal_code': '8530',
#   'Price': 379000,
#   'Subtype': 'VILLA',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 3,
#   'Living_area': 175,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'De Teerlink',
#   'number': '48',
#   'latitude': 50.849289,
#   'longitude': 3.3157617,
#   'landSurface': 606},
#  {'id': 20263033,
#   'locality_name': 'Ixelles',
#   'Postal_code': '1050',
#   'Price': 1995000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 544,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue Jean Baptiste Meunier',
#   'number': '19',
#   'latitude': 50.8147297,
#   'longitude': 4.3499737,
#   'landSurface': 666},
#  {'id': 20257839,
#   'locality_name': 'Bertrix',
#   'Postal_code': '6880',
#   'Price': 175000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 3,
#   'Living_area': 85,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue Champs Morais',
#   'number': '46',
#   'latitude': 49.8521412,
#   'longitude': 5.2633079,
#   'landSurface': 173},
#  {'id': 20257844,
#   'locality_name': 'Habay (Habay-la-Neuve)',
#   'Postal_code': '6720',
#   'Price': 425000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 2,
#   'Living_area': 128,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Avenue de la Gare',
#   'number': '78',
#   'latitude': 49.7225675,
#   'longitude': 5.6391773,
#   'landSurface': 490},
#  {'id': 20264924,
#   'locality_name': 'Wezembeek-Oppem',
#   'Postal_code': '1970',
#   'Price': 695000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 185,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': "Avenue des Boutons d'Or",
#   'number': '21',
#   'latitude': 50.839795,
#   'longitude': 4.480845,
#   'landSurface': 552},
#  {'id': 20260710,
#   'locality_name': 'Ronse',
#   'Postal_code': '9600',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rode Broeckstraat',
#   'number': '158',
#   'latitude': 50.73817940000001,
#   'longitude': 3.6059456,
#   'landSurface': None},
#  {'id': 20260196,
#   'locality_name': 'Oudsbergen',
#   'Postal_code': '3670',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Reigerstraat',
#   'number': None,
#   'latitude': 51.0785899,
#   'longitude': 5.5786658,
#   'landSurface': None},
#  {'id': 20261055,
#   'locality_name': 'Beersel',
#   'Postal_code': '1650',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Vroenenbosstraat',
#   'number': '28',
#   'latitude': 50.7276215,
#   'longitude': 4.2969265,
#   'landSurface': None},
#  {'id': 20261307,
#   'locality_name': 'Machelen',
#   'Postal_code': '1830',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Beemdgrachtstraat',
#   'number': '9',
#   'latitude': 50.895537,
#   'longitude': 4.4184493,
#   'landSurface': None},
#  {'id': 20261469,
#   'locality_name': 'Gent',
#   'Postal_code': '9000',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Heerweg-zuid',
#   'number': '193',
#   'latitude': 50.9969529,
#   'longitude': 3.7070249,
#   'landSurface': None},
#  {'id': 20261471,
#   'locality_name': 'Zwijnaarde',
#   'Postal_code': '9052',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Heerweg-zuid',
#   'number': '193',
#   'latitude': 50.9969529,
#   'longitude': 3.7070249,
#   'landSurface': None},
#  {'id': 20257815,
#   'locality_name': 'Chiny (Jamoigne)',
#   'Postal_code': '6810',
#   'Price': 320000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 197,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue Mottet',
#   'number': '1',
#   'latitude': 49.6953052,
#   'longitude': 5.4192733,
#   'landSurface': 292},
#  {'id': 20257810,
#   'locality_name': 'Libin (Transinne)',
#   'Postal_code': '6890',
#   'Price': 349000,
#   'Subtype': 'EXCEPTIONAL_PROPERTY',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 2,
#   'Living_area': 232,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': "Rue de l'Eglise",
#   'number': '2',
#   'latitude': 50.0000839,
#   'longitude': 5.203685699999999,
#   'landSurface': 969},
#  {'id': 20257825,
#   'locality_name': 'Habay (Habay-la-Neuve)',
#   'Postal_code': '6720',
#   'Price': 420000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 180,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue de la Colline',
#   'number': '1',
#   'latitude': 49.7339881,
#   'longitude': 5.6418479,
#   'landSurface': 461},
#  {'id': 20257841,
#   'locality_name': 'Arlon (Bonnert)',
#   'Postal_code': '6700',
#   'Price': 560000,
#   'Subtype': 'VILLA',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 3,
#   'Living_area': 119,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue du Vicinal',
#   'number': '104',
#   'latitude': 49.6996925,
#   'longitude': 5.813108,
#   'landSurface': 1690},
#  {'id': 20257813,
#   'locality_name': 'Etalle (Buzenol)',
#   'Postal_code': '6740',
#   'Price': 640000,
#   'Subtype': 'EXCEPTIONAL_PROPERTY',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 5,
#   'Living_area': 248,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue du Musée',
#   'number': '20',
#   'latitude': 49.6449307,
#   'longitude': 5.598759299999999,
#   'landSurface': 2760},
#  {'id': 20254967,
#   'locality_name': 'WETTEREN',
#   'Postal_code': '9230',
#   'Price': 740000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 252,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Den Blakkenlaan',
#   'number': '26',
#   'latitude': 51.008831,
#   'longitude': 3.9005888,
#   'landSurface': 1481},
#  {'id': 20260391,
#   'locality_name': 'DEURNE',
#   'Postal_code': '2100',
#   'Price': 379000,
#   'Subtype': 'TOWN_HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 186,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Stevenslei',
#   'number': '35',
#   'latitude': 51.2074723,
#   'longitude': 4.4677901,
#   'landSurface': 110},
#  {'id': 20260384,
#   'locality_name': 'DEURNE',
#   'Postal_code': '2100',
#   'Price': 379000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 186,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Stevenslei',
#   'number': '35',
#   'latitude': 51.2074723,
#   'longitude': 4.4677901,
#   'landSurface': 110},
#  {'id': 20260385,
#   'locality_name': 'DEURNE',
#   'Postal_code': '2100',
#   'Price': 379000,
#   'Subtype': 'EXCEPTIONAL_PROPERTY',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 186,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Stevenslei',
#   'number': '35',
#   'latitude': 51.2074723,
#   'longitude': 4.4677901,
#   'landSurface': 110},
#  {'id': 20257843,
#   'locality_name': 'Étalle (Buzenol)',
#   'Postal_code': '6740',
#   'Price': 295000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 3,
#   'Living_area': 110,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': "Chemin d'Etalle",
#   'number': '7',
#   'latitude': 49.6490632,
#   'longitude': 5.5958741,
#   'landSurface': 975},
#  {'id': 20258423,
#   'locality_name': 'ANTWERPEN',
#   'Postal_code': '2140',
#   'Price': 379900,
#   'Subtype': 'APARTMENT_BLOCK',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 3,
#   'Living_area': 156,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Schildstraat',
#   'number': '33',
#   'latitude': 51.2111765,
#   'longitude': 4.4356913,
#   'landSurface': 84},
#  {'id': 20257820,
#   'locality_name': 'Étalle',
#   'Postal_code': '6740',
#   'Price': 420000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 3,
#   'Living_area': 128,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue des Mésanges',
#   'number': '29',
#   'latitude': 49.6707648,
#   'longitude': 5.5942538,
#   'landSurface': 611},
#  {'id': 20257826,
#   'locality_name': 'Arlon (Heinsch)',
#   'Postal_code': '6700',
#   'Price': 435000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 174,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Route de Neufchâteau',
#   'number': '419',
#   'latitude': 49.6960825,
#   'longitude': 5.7583665,
#   'landSurface': 1440},
#  {'id': 20257819,
#   'locality_name': 'Habay (Rulles)',
#   'Postal_code': '6720',
#   'Price': 495000,
#   'Subtype': 'EXCEPTIONAL_PROPERTY',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 3,
#   'Living_area': 143,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue de la Bergerie',
#   'number': '2',
#   'latitude': 49.7262955,
#   'longitude': 5.5683354,
#   'landSurface': 5233},
#  {'id': 20257520,
#   'locality_name': 'Roeselare',
#   'Postal_code': '8800',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Gitsestraat',
#   'number': '545',
#   'latitude': 50.97100380000001,
#   'longitude': 3.1146049,
#   'landSurface': None},
#  {'id': 20258833,
#   'locality_name': 'Nazareth',
#   'Postal_code': '9810',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Hoogkouter',
#   'number': None,
#   'latitude': 50.9543212,
#   'longitude': 3.6351292,
#   'landSurface': None},
#  {'id': 20258529,
#   'locality_name': 'Sint-Amands',
#   'Postal_code': '2890',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Heidestraat',
#   'number': '63',
#   'latitude': 51.0571589,
#   'longitude': 4.208326,
#   'landSurface': None},
#  {'id': 20257646,
#   'locality_name': 'Lierde',
#   'Postal_code': '9570',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Doornkouter',
#   'number': None,
#   'latitude': 50.8131022,
#   'longitude': 3.876165,
#   'landSurface': None},
#  {'id': 20258797,
#   'locality_name': 'De Pinte',
#   'Postal_code': '9840',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Heirweg',
#   'number': '8',
#   'latitude': 50.9746003,
#   'longitude': 3.6435902,
#   'landSurface': None},
#  {'id': 20263841,
#   'locality_name': 'SINT-DENIJS',
#   'Postal_code': '8554',
#   'Price': 534000,
#   'Subtype': 'COUNTRY_COTTAGE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 2,
#   'Living_area': 170,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Kooigemstraat',
#   'number': '83',
#   'latitude': 50.74688889999999,
#   'longitude': 3.3455148,
#   'landSurface': 852},
#  {'id': 20264881,
#   'locality_name': 'HOBOKEN',
#   'Postal_code': '2660',
#   'Price': 314000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 132,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Heidestraat',
#   'number': '232',
#   'latitude': 51.17442339999999,
#   'longitude': 4.3648054,
#   'landSurface': 125},
#  {'id': 20264949,
#   'locality_name': 'WILLEBROEK',
#   'Postal_code': '2830',
#   'Price': 398000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 3,
#   'Living_area': 135,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Gezondheidsstraat',
#   'number': '7',
#   'latitude': 51.0552846,
#   'longitude': 4.360860499999999,
#   'landSurface': 136},
#  {'id': 20264801,
#   'locality_name': 'Vloesberg',
#   'Postal_code': '7880',
#   'Price': 605250,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 3,
#   'Living_area': 300,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Sainte-Anne',
#   'number': '2',
#   'latitude': 50.7569262,
#   'longitude': 3.7298833,
#   'landSurface': 2900},
#  {'id': 20241535,
#   'locality_name': 'ZWIJNDRECHT',
#   'Postal_code': '2070',
#   'Price': 424000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 215,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Kraaienhoflaan',
#   'number': '28',
#   'latitude': 51.20833100000001,
#   'longitude': 4.3436799,
#   'landSurface': 104},
#  {'id': 20261092,
#   'locality_name': 'DEURNE',
#   'Postal_code': '2100',
#   'Price': 642000,
#   'Subtype': 'MIXED_USE_BUILDING',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 9,
#   'Living_area': 267,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Boekenbergplein',
#   'number': '10',
#   'latitude': 51.2031663,
#   'longitude': 4.462396900000001,
#   'landSurface': 233},
#  {'id': 20259139,
#   'locality_name': 'BOORTMEERBEEK',
#   'Postal_code': '3190',
#   'Price': 896000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 464,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Bieststraat',
#   'number': '102',
#   'latitude': 50.9872336,
#   'longitude': 4.5541543,
#   'landSurface': 4853},
#  {'id': 20252354,
#   'locality_name': 'RONSE',
#   'Postal_code': '9600',
#   'Price': 319000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 3,
#   'Living_area': 125,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rotterij',
#   'number': '148',
#   'latitude': 50.744176,
#   'longitude': 3.625722199999999,
#   'landSurface': 767},
#  {'id': 20258341,
#   'locality_name': 'MECHELEN',
#   'Postal_code': '2800',
#   'Price': 389000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 163,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Oude Antwerpsebaan',
#   'number': '101',
#   'latitude': 51.0417153,
#   'longitude': 4.46765,
#   'landSurface': 235},
#  {'id': 20257954,
#   'locality_name': 'THIEU',
#   'Postal_code': '7070',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': None,
#   'number': None,
#   'latitude': None,
#   'longitude': None,
#   'landSurface': None},
#  {'id': 20258498,
#   'locality_name': 'Langemark-Poelkapelle',
#   'Postal_code': '8920',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Mangelaarstraat',
#   'number': '26',
#   'latitude': 50.93644219999999,
#   'longitude': 2.9121287,
#   'landSurface': None},
#  {'id': 20256079,
#   'locality_name': 'Geraardsbergen Moerbeke',
#   'Postal_code': '9500',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Brouwketelstraat',
#   'number': None,
#   'latitude': 50.7535926,
#   'longitude': 3.9257407,
#   'landSurface': None},
#  {'id': 20255074,
#   'locality_name': 'Leopoldsburg',
#   'Postal_code': '3970',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Burgemeester Steyaertstraat',
#   'number': '1-15',
#   'latitude': 51.1193793,
#   'longitude': 5.2497698,
#   'landSurface': None},
#  {'id': 20256142,
#   'locality_name': 'Deinze Astene',
#   'Postal_code': '9800',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Den Bunker',
#   'number': '1',
#   'latitude': 50.9825758,
#   'longitude': 3.5697702,
#   'landSurface': None},
#  {'id': 20253763,
#   'locality_name': 'Opwijk',
#   'Postal_code': '1745',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Asbeekweg',
#   'number': '35',
#   'latitude': 50.9698091,
#   'longitude': 4.2016776,
#   'landSurface': None},
#  {'id': 20258538,
#   'locality_name': 'Brugge',
#   'Postal_code': '8000',
#   'Price': 215000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 2,
#   'Living_area': 65,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Hoogstuk',
#   'number': '8',
#   'latitude': 51.2060993,
#   'longitude': 3.2362739,
#   'landSurface': 33},
#  {'id': 20259223,
#   'locality_name': 'TERHAGEN',
#   'Postal_code': '2840',
#   'Price': 325000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 3,
#   'Living_area': 164,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Hoogstraat',
#   'number': '35',
#   'latitude': 51.080759,
#   'longitude': 4.400447,
#   'landSurface': 165},
#  {'id': 20259288,
#   'locality_name': 'OETINGEN',
#   'Postal_code': '1755',
#   'Price': 560000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 350,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Blijkheerstraat',
#   'number': '70',
#   'latitude': 50.7754117,
#   'longitude': 4.0470571,
#   'landSurface': 3270},
#  {'id': 20259281,
#   'locality_name': 'OETINGEN',
#   'Postal_code': '1755',
#   'Price': 560000,
#   'Subtype': 'MIXED_USE_BUILDING',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 350,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Blijkheerstraat',
#   'number': '70',
#   'latitude': 50.7754117,
#   'longitude': 4.0470571,
#   'landSurface': 3270},
#  {'id': 20262904,
#   'locality_name': 'Knokke-Heist',
#   'Postal_code': '8300',
#   'Price': 6395000,
#   'Subtype': 'VILLA',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 5,
#   'Living_area': 368,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Tulpenlaan',
#   'number': '8',
#   'latitude': 51.34195339999999,
#   'longitude': 3.3181052,
#   'landSurface': 1143},
#  {'id': 20257842,
#   'locality_name': 'Aubange (Athus)',
#   'Postal_code': '6791',
#   'Price': 180000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 2,
#   'Living_area': 86,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue Neuve',
#   'number': '44',
#   'latitude': 49.5640739,
#   'longitude': 5.839239699999999,
#   'landSurface': 110},
#  {'id': 20257832,
#   'locality_name': 'Habay (Marbehan)',
#   'Postal_code': '6724',
#   'Price': 260000,
#   'Subtype': 'MIXED_USE_BUILDING',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 247,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': "Grand'Rue",
#   'number': '29',
#   'latitude': 49.7246238,
#   'longitude': 5.5369245,
#   'landSurface': 280},
#  {'id': 20257838,
#   'locality_name': 'Habay (Houdemont)',
#   'Postal_code': '6720',
#   'Price': 275000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 148,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue des Ecoles',
#   'number': '2',
#   'latitude': 49.7182434,
#   'longitude': 5.5859837,
#   'landSurface': 550},
#  {'id': 20257824,
#   'locality_name': 'Saint-Hubert',
#   'Postal_code': '6870',
#   'Price': 299000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 3,
#   'Living_area': 129,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue de Lavaux',
#   'number': '52',
#   'latitude': 50.0265496,
#   'longitude': 5.382783799999999,
#   'landSurface': 6682},
#  {'id': 20257823,
#   'locality_name': 'Arlon (Stockem)',
#   'Postal_code': '6700',
#   'Price': 395000,
#   'Subtype': 'APARTMENT_BLOCK',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 131,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue des Cheminots',
#   'number': '27',
#   'latitude': 49.6878385,
#   'longitude': 5.770455999999999,
#   'landSurface': 505},
#  {'id': 20264517,
#   'locality_name': 'Jette',
#   'Postal_code': '1090',
#   'Price': 419000,
#   'Subtype': 'TOWN_HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 3,
#   'Living_area': 203,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue Adolphe Vandenschrieck',
#   'number': '50',
#   'latitude': 50.87872280000001,
#   'longitude': 4.3266719,
#   'landSurface': 65},
#  {'id': 20256394,
#   'locality_name': 'Oupeye',
#   'Postal_code': '4680',
#   'Price': 319000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 5,
#   'Living_area': 260,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue Joseph Wauters',
#   'number': '73',
#   'latitude': 50.697163,
#   'longitude': 5.6516035,
#   'landSurface': 1102},
#  {'id': 20258863,
#   'locality_name': 'Ronse',
#   'Postal_code': '9600',
#   'Price': 399000,
#   'Subtype': 'VILLA',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 197,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rode Mutslaan',
#   'number': '34',
#   'latitude': 50.7435507,
#   'longitude': 3.5741264,
#   'landSurface': 992},
#  {'id': 20259297,
#   'locality_name': 'FLOBECQ',
#   'Postal_code': '7880',
#   'Price': 475000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 5,
#   'Living_area': 206,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Lumen',
#   'number': '30',
#   'latitude': 50.764247,
#   'longitude': 3.722272499999999,
#   'landSurface': 2500},
#  {'id': 20259275,
#   'locality_name': 'FLOBECQ',
#   'Postal_code': '7880',
#   'Price': 475000,
#   'Subtype': 'MIXED_USE_BUILDING',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 5,
#   'Living_area': 206,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Lumen',
#   'number': '30',
#   'latitude': 50.764247,
#   'longitude': 3.722272499999999,
#   'landSurface': 2500},
#  {'id': 20257259,
#   'locality_name': 'Wavre',
#   'Postal_code': '1300',
#   'Price': 650000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 262,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Chemin des Marêchaux',
#   'number': '35',
#   'latitude': 50.6983442,
#   'longitude': 4.608543,
#   'landSurface': 2363},
#  {'id': 20264142,
#   'locality_name': 'Oudenaarde',
#   'Postal_code': '9700',
#   'Price': 347500,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': 16,
#   'Number_of_bedrooms': 3,
#   'Living_area': 112,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Robert De Preesterstraat',
#   'number': '144',
#   'latitude': 50.8666564,
#   'longitude': 3.6449379,
#   'landSurface': 249},
#  {'id': 20252035,
#   'locality_name': 'Staden',
#   'Postal_code': '8840',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Kampstraat',
#   'number': '3',
#   'latitude': 50.9501006,
#   'longitude': 2.9786267,
#   'landSurface': None},
#  {'id': 20251611,
#   'locality_name': 'Gavere',
#   'Postal_code': '9890',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Slaapstraat',
#   'number': '8',
#   'latitude': 50.9145933,
#   'longitude': 3.6505555,
#   'landSurface': None},
#  {'id': 20254354,
#   'locality_name': 'Schelle',
#   'Postal_code': '2627',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Provinciale Steenweg',
#   'number': '241',
#   'latitude': 51.1224508,
#   'longitude': 4.3385675,
#   'landSurface': None},
#  {'id': 20252822,
#   'locality_name': 'Gent Sint-Amandsberg',
#   'Postal_code': '9040',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Sint-Bernadettestraat',
#   'number': '16',
#   'latitude': 51.0689974,
#   'longitude': 3.7505525,
#   'landSurface': None},
#  {'id': 20257834,
#   'locality_name': 'Tintigny (Saint-Vincent)',
#   'Postal_code': '6730',
#   'Price': 239000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 3,
#   'Living_area': 118,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': "Rue de l'Enfer",
#   'number': '221',
#   'latitude': 49.6757838,
#   'longitude': 5.4758454,
#   'landSurface': 6261},
#  {'id': 20257828,
#   'locality_name': 'Habay (Anlier)',
#   'Postal_code': '6720',
#   'Price': 295000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 2,
#   'Living_area': 129,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue de Maou',
#   'number': '12',
#   'latitude': 49.7707937,
#   'longitude': 5.6187919,
#   'landSurface': 347},
#  {'id': 20260111,
#   'locality_name': 'Lierneux',
#   'Postal_code': '4990',
#   'Price': 375000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': 13,
#   'Number_of_bedrooms': 3,
#   'Living_area': 183,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Verleumont',
#   'number': '4',
#   'latitude': 50.2739971,
#   'longitude': 5.808186999999999,
#   'landSurface': 1627},
#  {'id': 20262751,
#   'locality_name': 'HEUSDEN',
#   'Postal_code': '9070',
#   'Price': 490000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 2,
#   'Living_area': 110,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Spangerede',
#   'number': '17',
#   'latitude': 51.0261108,
#   'longitude': 3.8045331,
#   'landSurface': 1425},
#  {'id': 20254116,
#   'locality_name': 'LICHTAART',
#   'Postal_code': '2460',
#   'Price': 669000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 495,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Hoebenschot',
#   'number': '27',
#   'latitude': 51.2275831,
#   'longitude': 4.8963338,
#   'landSurface': 3681},
#  {'id': 20265106,
#   'locality_name': 'Paliseul',
#   'Postal_code': '6850',
#   'Price': 389000,
#   'Subtype': 'APARTMENT_BLOCK',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 3,
#   'Living_area': 260,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Place de la Gare',
#   'number': '1',
#   'latitude': 49.8954938,
#   'longitude': 5.1190465,
#   'landSurface': 403},
#  {'id': 20264744,
#   'locality_name': 'Neder-Over-Heembeek',
#   'Postal_code': '1120',
#   'Price': 679000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 6,
#   'Living_area': 240,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': "Venelle de l'Alchimiste",
#   'number': '14',
#   'latitude': 50.8978545,
#   'longitude': 4.394741499999999,
#   'landSurface': 356},
#  {'id': 20253578,
#   'locality_name': 'BORGERHOUT',
#   'Postal_code': '2140',
#   'Price': 169000,
#   'Subtype': 'MIXED_USE_BUILDING',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 2,
#   'Living_area': 112,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Prins Leopoldstraat',
#   'number': '79',
#   'latitude': 51.2118426,
#   'longitude': 4.4385176,
#   'landSurface': 97},
#  {'id': 20259270,
#   'locality_name': 'GALMAARDEN',
#   'Postal_code': '1570',
#   'Price': 175000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 3,
#   'Living_area': 215,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Plaatsstraat',
#   'number': '2',
#   'latitude': 50.7416777,
#   'longitude': 4.0052618,
#   'landSurface': 621},
#  {'id': 20256665,
#   'locality_name': 'Seraing',
#   'Postal_code': '4102',
#   'Price': 220000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 125,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue de la Démocratie',
#   'number': '71',
#   'latitude': 50.6014057,
#   'longitude': 5.5364242,
#   'landSurface': 230},
#  {'id': 20258996,
#   'locality_name': 'Lint',
#   'Postal_code': '2547',
#   'Price': 395000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 200,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Reynaertshof',
#   'number': '36',
#   'latitude': 51.1282656,
#   'longitude': 4.4841329,
#   'landSurface': 479},
#  {'id': 20251003,
#   'locality_name': 'GERAARDSBERGEN',
#   'Postal_code': '9500',
#   'Price': 299999,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 3,
#   'Living_area': 167,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Pirrestraat',
#   'number': '17',
#   'latitude': 50.7521206,
#   'longitude': 3.9254954,
#   'landSurface': 1050},
#  {'id': 20253465,
#   'locality_name': 'Engis',
#   'Postal_code': '4480',
#   'Price': 260000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 152,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue Reine Astrid',
#   'number': '62',
#   'latitude': 50.5867707,
#   'longitude': 5.400970099999999,
#   'landSurface': 696},
#  {'id': 20257811,
#   'locality_name': 'Chiny',
#   'Postal_code': '6810',
#   'Price': 285000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 324,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue de Lorrène',
#   'number': '25',
#   'latitude': 49.7386694,
#   'longitude': 5.3418531,
#   'landSurface': 610},
#  {'id': 20253598,
#   'locality_name': 'Brakel',
#   'Postal_code': '9660',
#   'Price': 317500,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': 19,
#   'Number_of_bedrooms': 4,
#   'Living_area': 220,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Warande',
#   'number': '3',
#   'latitude': 50.8027916,
#   'longitude': 3.7696459,
#   'landSurface': 319},
#  {'id': 20260633,
#   'locality_name': 'Roeselare',
#   'Postal_code': '8800',
#   'Price': 279000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': 1,
#   'Number_of_bedrooms': 4,
#   'Living_area': 167,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Kastanjestraat',
#   'number': '18',
#   'latitude': 50.9343567,
#   'longitude': 3.1157694,
#   'landSurface': 380},
#  {'id': 20261315,
#   'locality_name': 'Laeken',
#   'Postal_code': '1020',
#   'Price': 599000,
#   'Subtype': 'VILLA',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 200,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Avenue du Forum',
#   'number': '62',
#   'latitude': 50.9004539,
#   'longitude': 4.3572921,
#   'landSurface': 1200},
#  {'id': 20261983,
#   'locality_name': 'Torhout',
#   'Postal_code': '8820',
#   'Price': 659000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': 1,
#   'Number_of_bedrooms': 3,
#   'Living_area': 208,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Bruggestraat',
#   'number': '141',
#   'latitude': 51.078699,
#   'longitude': 3.1131208,
#   'landSurface': 3576},
#  {'id': 20260924,
#   'locality_name': 'Schaerbeek',
#   'Postal_code': '1030',
#   'Price': 675000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 185,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue Victor Vanderhoeft',
#   'number': '8',
#   'latitude': 50.8660037,
#   'longitude': 4.3962088,
#   'landSurface': 211},
#  {'id': 20261088,
#   'locality_name': 'Uccle',
#   'Postal_code': '1180',
#   'Price': 699000,
#   'Subtype': 'TOWN_HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 3,
#   'Living_area': 190,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Avenue de Messidor',
#   'number': '324',
#   'latitude': 50.81167,
#   'longitude': 4.3521069,
#   'landSurface': 150},
#  {'id': 20249506,
#   'locality_name': 'Deinze',
#   'Postal_code': '9800',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Bremkouter',
#   'number': '20-28',
#   'latitude': 50.9854895,
#   'longitude': 3.5856772,
#   'landSurface': None},
#  {'id': 20247946,
#   'locality_name': 'Ninove',
#   'Postal_code': '9400',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Geraardsbergsesteenweg',
#   'number': '137',
#   'latitude': 50.8552839,
#   'longitude': 3.9600696,
#   'landSurface': None},
#  {'id': 20244758,
#   'locality_name': 'Kortrijk',
#   'Postal_code': '8500',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Veemarkt',
#   'number': '0',
#   'latitude': 50.8265931,
#   'longitude': 3.2719637,
#   'landSurface': None},
#  {'id': 20249532,
#   'locality_name': 'Sint-Lievens-Houtem',
#   'Postal_code': '9520',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Paepevelden',
#   'number': '1 - 16',
#   'latitude': 50.94593099999999,
#   'longitude': 3.8629231,
#   'landSurface': None},
#  {'id': 20244772,
#   'locality_name': 'Kortrijk',
#   'Postal_code': '8500',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Veemarkt',
#   'number': '1',
#   'latitude': 50.8267278,
#   'longitude': 3.271899,
#   'landSurface': None},
#  {'id': 20249501,
#   'locality_name': 'Gent Mariakerke',
#   'Postal_code': '9030',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Speistraat',
#   'number': '16',
#   'latitude': 51.0856034,
#   'longitude': 3.6659281,
#   'landSurface': None},
#  {'id': 20246411,
#   'locality_name': 'Woluwe-Saint-Lambert',
#   'Postal_code': '1200',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue Albert et Marie-Louise Servais-Kinet',
#   'number': '32-36',
#   'latitude': 50.8452145,
#   'longitude': 4.4149236,
#   'landSurface': None},
#  {'id': 20246561,
#   'locality_name': 'Elsene',
#   'Postal_code': '1050',
#   'Price': None,
#   'Subtype': 'HOUSE_GROUP',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': None,
#   'Living_area': None,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue Du Printemps - Lentestraat',
#   'number': '57 - 61',
#   'latitude': 50.820728,
#   'longitude': 4.3891176,
#   'landSurface': None},
#  {'id': 20252931,
#   'locality_name': 'MECHELEN',
#   'Postal_code': '2800',
#   'Price': 595000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 3,
#   'Living_area': 160,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Sint-Lambertuslaan',
#   'number': '73',
#   'latitude': 51.0117626,
#   'longitude': 4.5104991,
#   'landSurface': 380},
#  {'id': 20251715,
#   'locality_name': 'Dilbeek',
#   'Postal_code': '1700',
#   'Price': 715000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': 19,
#   'Number_of_bedrooms': 3,
#   'Living_area': 280,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Herdebeekstraat 94-94a',
#   'number': '0',
#   'latitude': 50.84061,
#   'longitude': 4.2284253,
#   'landSurface': 374},
#  {'id': 20255510,
#   'locality_name': 'Schilde',
#   'Postal_code': '2970',
#   'Price': 779000,
#   'Subtype': 'VILLA',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 6,
#   'Living_area': 253,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Zonneweelde',
#   'number': '6',
#   'latitude': 51.27106,
#   'longitude': 4.562992299999999,
#   'landSurface': 1148},
#  {'id': 20264756,
#   'locality_name': 'LIERDE',
#   'Postal_code': '9570',
#   'Price': 444000,
#   'Subtype': 'MIXED_USE_BUILDING',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 249,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Hoogstraat',
#   'number': '177',
#   'latitude': 50.8123093,
#   'longitude': 3.8089341,
#   'landSurface': 590},
#  {'id': 20257885,
#   'locality_name': 'WILRIJK',
#   'Postal_code': '2610',
#   'Price': 215000,
#   'Subtype': 'MIXED_USE_BUILDING',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 2,
#   'Living_area': 84,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Populierenlaan',
#   'number': '1',
#   'latitude': 51.1842447,
#   'longitude': 4.392034499999999,
#   'landSurface': 718},
#  {'id': 20259885,
#   'locality_name': 'LOKEREN',
#   'Postal_code': '9160',
#   'Price': 288000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 3,
#   'Living_area': 195,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Heilig Hartlaan',
#   'number': '75',
#   'latitude': 51.0970966,
#   'longitude': 3.9887209,
#   'landSurface': 202},
#  {'id': 20259138,
#   'locality_name': 'MECHELEN',
#   'Postal_code': '2800',
#   'Price': 398000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 3,
#   'Living_area': 119,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Vaartdijk',
#   'number': '75',
#   'latitude': 51.01840989999999,
#   'longitude': 4.4768874,
#   'landSurface': 91},
#  {'id': 20252002,
#   'locality_name': 'MECHELEN',
#   'Postal_code': '2800',
#   'Price': 275000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 3,
#   'Living_area': 154,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Caputsteenstraat',
#   'number': '150',
#   'latitude': 51.0332691,
#   'longitude': 4.4917953,
#   'landSurface': 120},
#  {'id': 20252352,
#   'locality_name': 'Gooik',
#   'Postal_code': '1755',
#   'Price': 295000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 3,
#   'Living_area': 172,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Strijlandstraat',
#   'number': '45',
#   'latitude': 50.7918775,
#   'longitude': 4.0842927,
#   'landSurface': 309},
#  {'id': 20252468,
#   'locality_name': 'LEDE',
#   'Postal_code': '9340',
#   'Price': 399850,
#   'Subtype': 'VILLA',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 5,
#   'Living_area': 354,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Hoogstraat',
#   'number': '100',
#   'latitude': 50.959532,
#   'longitude': 3.9766242,
#   'landSurface': 651},
#  {'id': 20264511,
#   'locality_name': 'Schaerbeek',
#   'Postal_code': '1030',
#   'Price': 410000,
#   'Subtype': 'MIXED_USE_BUILDING',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 3,
#   'Living_area': 257,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue du Pavillon',
#   'number': '76',
#   'latitude': 50.86995659999999,
#   'longitude': 4.3708041,
#   'landSurface': 60},
#  {'id': 20254874,
#   'locality_name': 'Liège',
#   'Postal_code': '4000',
#   'Price': 149000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 121,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue Joseph Henrion',
#   'number': '8',
#   'latitude': 50.6502231,
#   'longitude': 5.555633299999999,
#   'landSurface': 120},
#  {'id': 20257882,
#   'locality_name': 'DEURNE',
#   'Postal_code': '2100',
#   'Price': 199000,
#   'Subtype': 'MIXED_USE_BUILDING',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 2,
#   'Living_area': 98,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Te Couwelaarlei',
#   'number': '103',
#   'latitude': 51.2231278,
#   'longitude': 4.4586648,
#   'landSurface': 667},
#  {'id': 20255986,
#   'locality_name': 'Auderghem',
#   'Postal_code': '1160',
#   'Price': 649000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': 12,
#   'Number_of_bedrooms': 4,
#   'Living_area': 170,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Jacques Bassem',
#   'number': '74',
#   'latitude': 50.8134276,
#   'longitude': 4.4289454,
#   'landSurface': 175},
#  {'id': 20254028,
#   'locality_name': 'Evere',
#   'Postal_code': '1140',
#   'Price': 726000,
#   'Subtype': 'APARTMENT_BLOCK',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 2,
#   'Living_area': 150,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Chaussée de Haecht',
#   'number': '988',
#   'latitude': 50.8727036,
#   'longitude': 4.398995,
#   'landSurface': 336},
#  {'id': 20256487,
#   'locality_name': 'KASTERLEE',
#   'Postal_code': '2460',
#   'Price': 895000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 5,
#   'Living_area': 335,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Vinkendreef',
#   'number': '5',
#   'latitude': 51.2057295,
#   'longitude': 4.8994747,
#   'landSurface': 2450},
#  {'id': 20257485,
#   'locality_name': 'KASTEELBRAKEL',
#   'Postal_code': '1440',
#   'Price': 899000,
#   'Subtype': 'MANSION',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 6,
#   'Living_area': 500,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue Joseph Wauters',
#   'number': '35',
#   'latitude': 50.6831281,
#   'longitude': 4.2936995,
#   'landSurface': 992},
#  {'id': 20257484,
#   'locality_name': 'Saintes',
#   'Postal_code': '1480',
#   'Price': 899000,
#   'Subtype': 'MANSION',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 6,
#   'Living_area': 500,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue Joseph Wauters',
#   'number': '35',
#   'latitude': 50.7043342,
#   'longitude': 4.1592946,
#   'landSurface': 992},
#  {'id': 20257482,
#   'locality_name': 'HALLE',
#   'Postal_code': '1500',
#   'Price': 899000,
#   'Subtype': 'MANSION',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 6,
#   'Living_area': 500,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue Joseph Wauters',
#   'number': '35',
#   'latitude': 50.8688575,
#   'longitude': 4.3920349,
#   'landSurface': 992},
#  {'id': 20257481,
#   'locality_name': 'LEMBEEK',
#   'Postal_code': '1502',
#   'Price': 899000,
#   'Subtype': 'MANSION',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 6,
#   'Living_area': 500,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue Joseph Wauters',
#   'number': '35',
#   'latitude': 50.7140616,
#   'longitude': 4.220043599999999,
#   'landSurface': 992},
#  {'id': 20257483,
#   'locality_name': 'PEPINGEN',
#   'Postal_code': '1670',
#   'Price': 899000,
#   'Subtype': 'MANSION',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 6,
#   'Living_area': 500,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue Joseph Wauters',
#   'number': '35',
#   'latitude': 50.7360287,
#   'longitude': 4.1360863,
#   'landSurface': 992},
#  {'id': 20262815,
#   'locality_name': 'WAREGEM',
#   'Postal_code': '8790',
#   'Price': 315000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 3,
#   'Living_area': 175,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Muizelstraat',
#   'number': '58',
#   'latitude': 50.8889643,
#   'longitude': 3.4230584,
#   'landSurface': 139},
#  {'id': 20260905,
#   'locality_name': 'Liedekerke',
#   'Postal_code': '1770',
#   'Price': 495000,
#   'Subtype': 'BUNGALOW',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 175,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Kerselarenlaan',
#   'number': '35',
#   'latitude': 50.8571335,
#   'longitude': 4.1240021,
#   'landSurface': 781},
#  {'id': 20260333,
#   'locality_name': 'Saint-Gilles',
#   'Postal_code': '1060',
#   'Price': 550000,
#   'Subtype': 'APARTMENT_BLOCK',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 6,
#   'Living_area': 287,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue de Hollande',
#   'number': '50',
#   'latitude': 50.8344195,
#   'longitude': 4.339686299999999,
#   'landSurface': 170},
#  {'id': 20260332,
#   'locality_name': 'Saint-Gilles',
#   'Postal_code': '1060',
#   'Price': 550000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 7,
#   'Living_area': 287,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue de Hollande',
#   'number': '50',
#   'latitude': 50.8344195,
#   'longitude': 4.339686299999999,
#   'landSurface': 180},
#  {'id': 20262809,
#   'locality_name': 'Oostkamp',
#   'Postal_code': '8020',
#   'Price': 625000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': 1,
#   'Number_of_bedrooms': 4,
#   'Living_area': 241,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Speienstraat',
#   'number': '44',
#   'latitude': 51.0719506,
#   'longitude': 3.168908,
#   'landSurface': 1160},
#  {'id': 20260277,
#   'locality_name': 'Brasschaat',
#   'Postal_code': '2930',
#   'Price': 845000,
#   'Subtype': 'VILLA',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 295,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Alfredlei',
#   'number': '36',
#   'latitude': 51.2887593,
#   'longitude': 4.454191,
#   'landSurface': 1115},
#  {'id': 20260021,
#   'locality_name': 'MEISE',
#   'Postal_code': '1860',
#   'Price': 995000,
#   'Subtype': 'VILLA',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 5,
#   'Living_area': 450,
#   'sale_annuity': None,
# ...
#   'landSurface': 220},
#  {'id': 20246608,
#   'locality_name': 'Archennes',
#   'Postal_code': '1390',
#   'Price': 350000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': 25,
#   'Number_of_bedrooms': 4,
#   'Living_area': 232,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Petite Rue des Prés',
#   'number': '8',
#   'latitude': 50.7388387,
#   'longitude': 4.661693,
#   'landSurface': 578},
#  {'id': 20250995,
#   'locality_name': 'GERAARDSBERGEN',
#   'Postal_code': '9500',
#   'Price': 360000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 170,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Edingseweg',
#   'number': '289',
#   'latitude': 50.7527325,
#   'longitude': 3.9165651,
#   'landSurface': 305},
#  {'id': 20250990,
#   'locality_name': 'GERAARDSBERGEN',
#   'Postal_code': '9500',
#   'Price': 360000,
#   'Subtype': 'MIXED_USE_BUILDING',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 170,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Edingseweg',
#   'number': '289',
#   'latitude': 50.7527325,
#   'longitude': 3.9165651,
#   'landSurface': 305},
#  {'id': 20245887,
#   'locality_name': 'Amougies',
#   'Postal_code': '7750',
#   'Price': 369000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': 1,
#   'Number_of_bedrooms': 0,
#   'Living_area': 149,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue Rouge-Croix',
#   'number': '48',
#   'latitude': 50.7471215,
#   'longitude': 3.5113066,
#   'landSurface': 1258},
#  {'id': 20249989,
#   'locality_name': 'NINOVE',
#   'Postal_code': '9400',
#   'Price': 399500,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 248,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Denderhoutembaan',
#   'number': '88',
#   'latitude': 50.8440099,
#   'longitude': 4.020881,
#   'landSurface': 0},
#  {'id': 20247461,
#   'locality_name': 'Gavere',
#   'Postal_code': '9890',
#   'Price': 479000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': 12,
#   'Number_of_bedrooms': 3,
#   'Living_area': 217,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Vossestraat',
#   'number': '40',
#   'latitude': 50.9317872,
#   'longitude': 3.6618412,
#   'landSurface': 1591},
#  {'id': 20246455,
#   'locality_name': 'Gent',
#   'Postal_code': '9000',
#   'Price': 619000,
#   'Subtype': 'APARTMENT_BLOCK',
#   'Number_of_rooms': 17,
#   'Number_of_bedrooms': 4,
#   'Living_area': 247,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Sint-Pietersaalststraat',
#   'number': '79',
#   'latitude': 51.0303735,
#   'longitude': 3.7159768,
#   'landSurface': 140},
#  {'id': 20244987,
#   'locality_name': 'Gavere',
#   'Postal_code': '9890',
#   'Price': 675000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': 1,
#   'Number_of_bedrooms': 5,
#   'Living_area': 446,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Nieuwlandstraat',
#   'number': '23',
#   'latitude': 50.935714,
#   'longitude': 3.6364274,
#   'landSurface': 2118},
#  {'id': 20246961,
#   'locality_name': 'Herent',
#   'Postal_code': '3020',
#   'Price': 798000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': 1,
#   'Number_of_bedrooms': 4,
#   'Living_area': 210,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Maleizenstraat',
#   'number': '59',
#   'latitude': 50.8901846,
#   'longitude': 4.6605979,
#   'landSurface': 882},
#  {'id': 20245449,
#   'locality_name': 'Knokke-Heist',
#   'Postal_code': '8301',
#   'Price': 1095000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 6,
#   'Living_area': 262,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Middenschip',
#   'number': '81',
#   'latitude': 51.32983770000001,
#   'longitude': 3.2479424,
#   'landSurface': 285},
#  {'id': 20251573,
#   'locality_name': 'AALST',
#   'Postal_code': '9300',
#   'Price': 1350000,
#   'Subtype': 'MANSION',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 5,
#   'Living_area': 992,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Keizersplein',
#   'number': '47-49',
#   'latitude': 50.9359945,
#   'longitude': 4.037028800000001,
#   'landSurface': 590},
#  {'id': 20251572,
#   'locality_name': 'AALST',
#   'Postal_code': '9300',
#   'Price': 1350000,
#   'Subtype': 'EXCEPTIONAL_PROPERTY',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 5,
#   'Living_area': 992,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Keizersplein',
#   'number': '47-49',
#   'latitude': 50.9359945,
#   'longitude': 4.037028800000001,
#   'landSurface': 590},
#  {'id': 20251574,
#   'locality_name': 'AALST',
#   'Postal_code': '9300',
#   'Price': 1350000,
#   'Subtype': 'EXCEPTIONAL_PROPERTY',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 5,
#   'Living_area': 992,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Keizersplein',
#   'number': '47-49',
#   'latitude': 50.9359945,
#   'longitude': 4.037028800000001,
#   'landSurface': 590},
#  {'id': 20251569,
#   'locality_name': 'AALST',
#   'Postal_code': '9300',
#   'Price': 1350000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 5,
#   'Living_area': 992,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Keizersplein',
#   'number': '47-49',
#   'latitude': 50.9359945,
#   'longitude': 4.037028800000001,
#   'landSurface': 590},
#  {'id': 20247265,
#   'locality_name': 'Deurle',
#   'Postal_code': '9831',
#   'Price': 2380000,
#   'Subtype': 'VILLA',
#   'Number_of_rooms': 1,
#   'Number_of_bedrooms': 6,
#   'Living_area': 558,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Nevelse Warande',
#   'number': '29',
#   'latitude': 51.0091021,
#   'longitude': 3.6142768,
#   'landSurface': 3592},
#  {'id': 20228162,
#   'locality_name': 'SCHOTEN',
#   'Postal_code': '2900',
#   'Price': 1150000,
#   'Subtype': 'EXCEPTIONAL_PROPERTY',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 360,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Valkenlaan',
#   'number': '11',
#   'latitude': 51.2461941,
#   'longitude': 4.5196353,
#   'landSurface': 2618},
#  {'id': 20264430,
#   'locality_name': 'FRASNES-LEZ-ANVAING',
#   'Postal_code': '7910',
#   'Price': 749000,
#   'Subtype': 'COUNTRY_COTTAGE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 6,
#   'Living_area': 400,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Chemin du Carnois',
#   'number': '25',
#   'latitude': 50.6962177,
#   'longitude': 3.5700924,
#   'landSurface': 2474},
#  {'id': 20264432,
#   'locality_name': 'POTTES',
#   'Postal_code': '7760',
#   'Price': 785000,
#   'Subtype': 'COUNTRY_COTTAGE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 8,
#   'Living_area': 430,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue du Palais',
#   'number': '52',
#   'latitude': 50.7256009,
#   'longitude': 3.4165373,
#   'landSurface': 9610},
#  {'id': 20241168,
#   'locality_name': 'Han-sur-Lesse',
#   'Postal_code': '5580',
#   'Price': 249000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 8,
#   'Living_area': 340,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': "Rue d'Hamptay",
#   'number': '63',
#   'latitude': 50.1244413,
#   'longitude': 5.18922,
#   'landSurface': 520},
#  {'id': 20241167,
#   'locality_name': 'Han-sur-Lesse',
#   'Postal_code': '5580',
#   'Price': 249000,
#   'Subtype': 'APARTMENT_BLOCK',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 8,
#   'Living_area': 340,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': "Rue d'Hamptay",
#   'number': '63',
#   'latitude': 50.1244413,
#   'longitude': 5.18922,
#   'landSurface': 520},
#  {'id': 20240917,
#   'locality_name': 'Lede',
#   'Postal_code': '9340',
#   'Price': 299000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 225,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Hoogstraat',
#   'number': '13',
#   'latitude': 50.9643783,
#   'longitude': 3.9770907,
#   'landSurface': 210},
#  {'id': 20242753,
#   'locality_name': 'Stasegem',
#   'Postal_code': '8530',
#   'Price': 365000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': 9,
#   'Number_of_bedrooms': 2,
#   'Living_area': 181,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Klein Katrol',
#   'number': '10',
#   'latitude': 50.8337561,
#   'longitude': 3.3099936,
#   'landSurface': 574},
#  {'id': 20243606,
#   'locality_name': 'BEVEREN',
#   'Postal_code': '9130',
#   'Price': 375000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 2,
#   'Living_area': 166,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Binnendijk',
#   'number': '3',
#   'latitude': 51.255052,
#   'longitude': 4.1916551,
#   'landSurface': 374},
#  {'id': 20242743,
#   'locality_name': 'Mechelen',
#   'Postal_code': '2800',
#   'Price': 399000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': 11,
#   'Number_of_bedrooms': 3,
#   'Living_area': 240,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Zepstraat',
#   'number': '67',
#   'latitude': 51.0090538,
#   'longitude': 4.4242832,
#   'landSurface': 848},
#  {'id': 20242740,
#   'locality_name': 'Hombeek',
#   'Postal_code': '2811',
#   'Price': 399000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': 11,
#   'Number_of_bedrooms': 3,
#   'Living_area': 240,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Zepstraat',
#   'number': '67',
#   'latitude': 51.0090538,
#   'longitude': 4.4242832,
#   'landSurface': 848},
#  {'id': 20242719,
#   'locality_name': 'Aalst (9300)',
#   'Postal_code': '9300',
#   'Price': 399000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': 14,
#   'Number_of_bedrooms': 3,
#   'Living_area': 180,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Opwijkse Steenweg',
#   'number': '14',
#   'latitude': 50.9048099,
#   'longitude': 4.0555339,
#   'landSurface': 527},
#  {'id': 20242722,
#   'locality_name': 'Moorsel',
#   'Postal_code': '9310',
#   'Price': 399000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': 14,
#   'Number_of_bedrooms': 3,
#   'Living_area': 180,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Opwijkse Steenweg',
#   'number': '14',
#   'latitude': 50.9478217,
#   'longitude': 4.0983842,
#   'landSurface': 527},
#  {'id': 20243376,
#   'locality_name': 'ZULZEKE',
#   'Postal_code': '9690',
#   'Price': 555000,
#   'Subtype': 'VILLA',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 550,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Zandstraat',
#   'number': '12',
#   'latitude': 50.7609269,
#   'longitude': 3.5687011,
#   'landSurface': 7076},
#  {'id': 20241683,
#   'locality_name': 'MECHELEN',
#   'Postal_code': '2800',
#   'Price': 599000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 3,
#   'Living_area': 169,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Driesstraat',
#   'number': '6',
#   'latitude': 51.0029017,
#   'longitude': 4.4321891,
#   'landSurface': 355},
#  {'id': 20241682,
#   'locality_name': 'HOMBEEK',
#   'Postal_code': '2811',
#   'Price': 599000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 3,
#   'Living_area': 169,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Driesstraat',
#   'number': '6',
#   'latitude': 51.0029017,
#   'longitude': 4.4321891,
#   'landSurface': 355},
#  {'id': 20243425,
#   'locality_name': 'WAREGEM',
#   'Postal_code': '8790',
#   'Price': 790000,
#   'Subtype': 'VILLA',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 350,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Wortegemseweg',
#   'number': '94',
#   'latitude': 50.872938,
#   'longitude': 3.4525155,
#   'landSurface': 2396},
#  {'id': 20241460,
#   'locality_name': 'Meise',
#   'Postal_code': '1860',
#   'Price': 849000,
#   'Subtype': 'EXCEPTIONAL_PROPERTY',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 6,
#   'Living_area': 305,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Nieuwelaan',
#   'number': '39',
#   'latitude': 50.939532,
#   'longitude': 4.3267163,
#   'landSurface': 2252},
#  {'id': 20220403,
#   'locality_name': 'WAVRE',
#   'Postal_code': '1300',
#   'Price': 300000,
#   'Subtype': 'MIXED_USE_BUILDING',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 1,
#   'Living_area': 121,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Rue Constant Deraedt',
#   'number': '25',
#   'latitude': 50.7159774,
#   'longitude': 4.6111678,
#   'landSurface': 90},
#  {'id': 20257124,
#   'locality_name': 'HUY',
#   'Postal_code': '4500',
#   'Price': 129000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 2,
#   'Living_area': 110,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Chaussée Napoléon',
#   'number': '22',
#   'latitude': 50.5158517,
#   'longitude': 5.2297705,
#   'landSurface': 4804},
#  {'id': 20255897,
#   'locality_name': 'Lierde',
#   'Postal_code': '9570',
#   'Price': 165000,
#   'Subtype': 'FARMHOUSE',
#   'Number_of_rooms': 10,
#   'Number_of_bedrooms': 4,
#   'Living_area': 130,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Kakebeke',
#   'number': '14',
#   'latitude': 50.8244622,
#   'longitude': 3.8606241,
#   'landSurface': 235},
#  {'id': 20255952,
#   'locality_name': 'Vlierzele',
#   'Postal_code': '9520',
#   'Price': 169000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': 9,
#   'Number_of_bedrooms': 2,
#   'Living_area': 160,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Letterbroek',
#   'number': '17',
#   'latitude': 50.9340558,
#   'longitude': 3.8906651,
#   'landSurface': 481},
#  {'id': 20256434,
#   'locality_name': 'Izegem',
#   'Postal_code': '8870',
#   'Price': 315000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': 4,
#   'Number_of_bedrooms': 3,
#   'Living_area': 189,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Baronstraat',
#   'number': '153',
#   'latitude': 50.92703100000001,
#   'longitude': 3.218421,
#   'landSurface': 112},
#  {'id': 20255888,
#   'locality_name': 'Meulebeke',
#   'Postal_code': '8760',
#   'Price': 349000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': 13,
#   'Number_of_bedrooms': 2,
#   'Living_area': 175,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Paanderstraat',
#   'number': '40',
#   'latitude': 50.9360463,
#   'longitude': 3.3057987,
#   'landSurface': 2020},
#  {'id': 20258703,
#   'locality_name': 'Gent',
#   'Postal_code': '9000',
#   'Price': 355000,
#   'Subtype': 'MIXED_USE_BUILDING',
#   'Number_of_rooms': 11,
#   'Number_of_bedrooms': 3,
#   'Living_area': 111,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Pantserschipstraat',
#   'number': '141',
#   'latitude': 51.0907057,
#   'longitude': 3.7273052,
#   'landSurface': 120},
#  {'id': 20257137,
#   'locality_name': 'HOEVENEN',
#   'Postal_code': '2940',
#   'Price': 369000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 178,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Witvenstraat',
#   'number': '206',
#   'latitude': 51.3095429,
#   'longitude': 4.4113481,
#   'landSurface': 97},
#  {'id': 20257136,
#   'locality_name': 'HOEVENEN',
#   'Postal_code': '2940',
#   'Price': 369000,
#   'Subtype': 'APARTMENT_BLOCK',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 4,
#   'Living_area': 178,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Witvenstraat',
#   'number': '206',
#   'latitude': 51.3095429,
#   'longitude': 4.4113481,
#   'landSurface': 97},
#  {'id': 20254517,
#   'locality_name': 'Dilbeek Groot-Bijgaarden',
#   'Postal_code': '1702',
#   'Price': 375000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 3,
#   'Living_area': 150,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Kasteellaan',
#   'number': '6',
#   'latitude': 50.8711694,
#   'longitude': 4.2554396,
#   'landSurface': 408},
#  {'id': 20256207,
#   'locality_name': 'Boortmeerbeek',
#   'Postal_code': '3190',
#   'Price': 398000,
#   'Subtype': 'HOUSE',
#   'Number_of_rooms': None,
#   'Number_of_bedrooms': 2,
#   'Living_area': 196,
#   'sale_annuity': None,
#   'Type_of_sale': 'FOR_SALE',
#   'street': 'Laarstraat',
#   'number': '12',
#   'latitude': 50.9704338,
#   'longitude': 4.583790599999999,
#   'landSurface': 641},
#  ...]

# %%
# Convert listings_1 to DataFrame and export to CSV
dataframe_first_scrape = pd.DataFrame(listings_1)
csv_path = r"C:\Users\Rik\Desktop\immoeliza\scraper\immo_scraper_2_land.csv"
dataframe_first_scrape.to_csv(csv_path, index=False)

print(f"Data from first scrape saved to {csv_path}")
# Out:
# Data from first scrape saved to C:\Users\Rik\Desktop\immoeliza\scraper\immo_scraper_2_land.csv

# %%
## SECOND SCRAPE: This is the scrape of the individual house pages

print("Start second scraping")
    
data_collection_2 = []

for property in listings_1:
    
    base_url = "https://www.immoweb.be/nl/zoekertje/"
    property_url = base_url + str(property['id'])
    
    try:
        # Send request to property URL
        r = requests.get(property_url, headers=headers)
        r.raise_for_status()  
        
        # Parse the page content
        soup = BeautifulSoup(r.content, "html.parser")
        print(f"Page {property_url} scraped successfully.")
        
        # Try to extract the specific script tag
        script_tag = soup.select_one('div.classified script[type="text/javascript"]')
        
        if script_tag:
            # Process the script_tag here
            print("Script tag found and processed.")
        else:
            print(f"No script tag found on {property_url}")
    
    except Exception as e:
        # Print the error message and continue to the next property
        print(f"Error on page {property_url}: {e}")
        continue
    
    # Extract the JavaScript object
    js_content = script_tag.string
    
    # Find the start and end of the JSON object
    start = js_content.find('{')
    end = js_content.rfind('}') + 1
    
    # Extract and parse the JSON data
    json_data = json.loads(js_content[start:end])
    
    #append json_data to the list data_collection2
    data_collection_2.append(json_data)
# Out:
# Start second scraping
# Page https://www.immoweb.be/nl/zoekertje/20264804 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20260393 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20260850 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20254029 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20262954 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20264095 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20264349 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20263033 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20257839 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20257844 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20264924 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20260710 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20260196 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20261055 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20261307 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20261469 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20261471 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20257815 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20257810 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20257825 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20257841 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20257813 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20254967 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20260391 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20260384 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20260385 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20257843 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20258423 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20257820 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20257826 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20257819 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20257520 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20258833 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20258529 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20257646 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20258797 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20263841 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20264881 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20264949 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20264801 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20241535 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20261092 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20259139 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20252354 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20258341 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20257954 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20258498 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20256079 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20255074 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20256142 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20253763 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20258538 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20259223 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20259288 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20259281 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20262904 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20257842 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20257832 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20257838 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20257824 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20257823 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20264517 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20256394 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20258863 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20259297 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20259275 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20257259 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20264142 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20252035 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20251611 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20254354 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20252822 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20257834 scraped successfully.
# Script tag found and processed.
# Page https://www.immoweb.be/nl/zoekertje/20257828 scraped successfully.
# Script tag found and processed.

# %%
#Here i create a json file with the data for one individual listing/house that i scraped during the second scrape
with open('listings_second_scrape_test.json', 'w') as f:
    json.dump(data_collection_2[15], f, indent=4)

# %%
#parse en merge the data from data_collection_2 in listings_2
listings_2 = []

for house in data_collection_2:
    listing_2 = {}
    
    
    listing_2['id'] = house.get('id', None)
    
    
    property_details = house.get('property', {})

    listing_2['Open_fire'] = property_details.get('fireplaceExists', None)
    
    listing_2['Swimming_Pool'] = property_details.get('hasSwimmingPool', None)
    
    listing_2['hasTerrace'] = property_details.get('hasTerrace', None)
    
    listing_2['terraceSurface'] = property_details.get('terraceSurface', None)
    
    listing_2['hasGarden'] = property_details.get('hasGarden', None)
    
    listing_2['gardenSurface'] = property_details.get('gardenSurface', None)
    
    
    kitchen_details = property_details.get('kitchen', {})
    
    if isinstance(kitchen_details, dict):
        listing_2['Kitchen_type'] = kitchen_details.get('type', None)
    else:
        listing_2['Kitchen_type'] = None
        
    
    building_details = property_details.get('building',{})
    
    if isinstance(building_details, dict):
        listing_2['Number_of_facades'] = building_details.get('facadeCount', None)
    else:
        listing_2['Number_of_facades'] = None
    
    if isinstance(building_details, dict):
        listing_2['State_of_building'] = building_details.get('condition', None)
    else:
        listing_2['State_of_building'] = None
    
    
    transaction_details = house.get('transaction',{})
    
    
    sale_details = transaction_details.get('sale',{})
    
    if isinstance(sale_details, dict):
        listing_2['Furnished'] = sale_details.get('isFurnished', None)
    else:
        listing_2['Furnished'] = None
    
    if isinstance(sale_details, dict):
        listing_2['Starting_price'] = sale_details.get('hasStartingPrice', None)
    else:
        listing_2['Starting_price'] = None
    
    certificates = transaction_details.get('certificates', {})
    
    if isinstance(certificates, dict):
        listing_2['epc'] = certificates.get('epcScore', None)
    else:
        listing_2['epc'] = None
    
    listings_2.append(listing_2)

# %%
#Here i test one element (= one id/house) in listings_2
listings_2[24]
# Out:
# {'id': 20260384,
#  'Open_fire': False,
#  'Swimming_Pool': None,
#  'hasTerrace': None,
#  'terraceSurface': None,
#  'hasGarden': True,
#  'gardenSurface': 24,
#  'Kitchen_type': 'INSTALLED',
#  'Number_of_facades': 2,
#  'State_of_building': 'GOOD',
#  'Furnished': None,
#  'Starting_price': None,
#  'epc': 'D'}

# %%
#Creating a dataframe of listings_2

dataframe_second_scrape = pd.DataFrame(listings_2)
csv_path = r"C:\Users\Rik\Desktop\immoeliza\scraper\immo_scraper_land.csv"
dataframe_second_scrape.to_csv(csv_path, index=False)

print(f"Data from second scrape saved to {csv_path}")
# Out:
# Data from second scrape saved to C:\Users\Rik\Desktop\immoeliza\scraper\immo_scraper_land.csv

# %%
# Merge all the data (listings_1 & listings_2) on key id

merged_df = pd.merge(dataframe_first_scrape, dataframe_second_scrape, on='id', how='inner')

print(merged_df)
csv_path = r"C:\Users\Rik\Desktop\immoeliza\scraper\immo_scraper_merged_land.csv"
merged_df.to_csv(csv_path, index=False)

print(f"Merged data saved to {csv_path}")
# Out:
#           id             locality_name Postal_code      Price  \
# 0   20264804                  Wetteren        9230        NaN
# 1   20260393                Schaerbeek        1030   495000.0
# 2   20260850       Woluwe-Saint-Pierre        1150   575000.0
# 3   20254029        SINT-PIETERS-LEEUW        1600   449000.0
# 4   20262954  Geraardsbergen Ophasselt        9500        NaN
# 5   20264095            Oostnieuwkerke        8840        NaN
# 6   20264349                 HARELBEKE        8530   379000.0
# 7   20263033                   Ixelles        1050  1995000.0
# 8   20257839                   Bertrix        6880   175000.0
# 9   20257844    Habay (Habay-la-Neuve)        6720   425000.0
# 10  20264924           Wezembeek-Oppem        1970   695000.0
# 11  20260710                     Ronse        9600        NaN
# 12  20260196                Oudsbergen        3670        NaN
# 13  20261055                   Beersel        1650        NaN
# 14  20261307                  Machelen        1830        NaN
# 15  20261469                      Gent        9000        NaN
# 16  20261471                Zwijnaarde        9052        NaN
# 17  20257815          Chiny (Jamoigne)        6810   320000.0
# 18  20257810         Libin (Transinne)        6890   349000.0
# 19  20257825    Habay (Habay-la-Neuve)        6720   420000.0
# 20  20257841           Arlon (Bonnert)        6700   560000.0
# 21  20257813          Etalle (Buzenol)        6740   640000.0
# 22  20254967                  WETTEREN        9230   740000.0
# 23  20260391                    DEURNE        2100   379000.0
# 24  20260384                    DEURNE        2100   379000.0
# 25  20260385                    DEURNE        2100   379000.0
# 26  20257843          Étalle (Buzenol)        6740   295000.0
# 27  20258423                 ANTWERPEN        2140   379900.0
# 28  20257820                    Étalle        6740   420000.0
# 29  20257826           Arlon (Heinsch)        6700   435000.0
# 30  20257819            Habay (Rulles)        6720   495000.0
# 31  20257520                 Roeselare        8800        NaN
# 32  20258833                  Nazareth        9810        NaN
# 33  20258529               Sint-Amands        2890        NaN
# 34  20257646                    Lierde        9570        NaN
# 35  20258797                  De Pinte        9840        NaN
# 36  20263841               SINT-DENIJS        8554   534000.0
# 37  20264881                   HOBOKEN        2660   314000.0
# 38  20264949                WILLEBROEK        2830   398000.0
# 39  20264801                 Vloesberg        7880   605250.0
# 40  20241535               ZWIJNDRECHT        2070   424000.0
# 41  20261092                    DEURNE        2100   642000.0
# 42  20259139             BOORTMEERBEEK        3190   896000.0
# 43  20252354                     RONSE        9600   319000.0
# 44  20258341                  MECHELEN        2800   389000.0
# 45  20257954                     THIEU        7070        NaN
# 46  20258498     Langemark-Poelkapelle        8920        NaN
# 47  20256079   Geraardsbergen Moerbeke        9500        NaN
# 48  20255074              Leopoldsburg        3970        NaN
# 49  20256142             Deinze Astene        9800        NaN
# 50  20253763                    Opwijk        1745        NaN
# 51  20258538                    Brugge        8000   215000.0
# 52  20259223                  TERHAGEN        2840   325000.0
# 53  20259288                  OETINGEN        1755   560000.0
# 54  20259281                  OETINGEN        1755   560000.0
# 55  20262904              Knokke-Heist        8300  6395000.0
# 56  20257842           Aubange (Athus)        6791   180000.0
# 57  20257832          Habay (Marbehan)        6724   260000.0
# 58  20257838         Habay (Houdemont)        6720   275000.0
# 59  20257824              Saint-Hubert        6870   299000.0
#
#                  Subtype Number_of_rooms  Number_of_bedrooms  Living_area  \
# 0            HOUSE_GROUP            None                 NaN          NaN
# 1                  HOUSE            None                 3.0        120.0
# 2                  HOUSE            None                 5.0        177.0
# 3                  HOUSE            None                 2.0        121.0
# 4            HOUSE_GROUP            None                 NaN          NaN
# 5            HOUSE_GROUP            None                 NaN          NaN
# 6                  VILLA            None                 3.0        175.0
# 7                  HOUSE            None                 4.0        544.0
# 8                  HOUSE            None                 3.0         85.0
# 9                  HOUSE            None                 2.0        128.0
# 10                 HOUSE            None                 4.0        185.0
# 11           HOUSE_GROUP            None                 NaN          NaN
# 12           HOUSE_GROUP            None                 NaN          NaN
# 13           HOUSE_GROUP            None                 NaN          NaN
# 14           HOUSE_GROUP            None                 NaN          NaN
# 15           HOUSE_GROUP            None                 NaN          NaN
# 16           HOUSE_GROUP            None                 NaN          NaN
# 17                 HOUSE            None                 4.0        197.0
# 18  EXCEPTIONAL_PROPERTY            None                 2.0        232.0
# 19                 HOUSE            None                 4.0        180.0
# 20                 VILLA            None                 3.0        119.0
# 21  EXCEPTIONAL_PROPERTY            None                 5.0        248.0
# 22                 HOUSE            None                 4.0        252.0
# 23            TOWN_HOUSE            None                 4.0        186.0
# 24                 HOUSE            None                 4.0        186.0
# 25  EXCEPTIONAL_PROPERTY            None                 4.0        186.0
# 26                 HOUSE            None                 3.0        110.0
# 27       APARTMENT_BLOCK            None                 3.0        156.0
# 28                 HOUSE            None                 3.0        128.0
# 29                 HOUSE            None                 4.0        174.0
# 30  EXCEPTIONAL_PROPERTY            None                 3.0        143.0
# 31           HOUSE_GROUP            None                 NaN          NaN
# 32           HOUSE_GROUP            None                 NaN          NaN
# 33           HOUSE_GROUP            None                 NaN          NaN
# 34           HOUSE_GROUP            None                 NaN          NaN
# 35           HOUSE_GROUP            None                 NaN          NaN
# 36       COUNTRY_COTTAGE            None                 2.0        170.0
# 37                 HOUSE            None                 4.0        132.0
# 38                 HOUSE            None                 3.0        135.0
# 39                 HOUSE            None                 3.0        300.0
# 40                 HOUSE            None                 4.0        215.0
# 41    MIXED_USE_BUILDING            None                 9.0        267.0
# 42                 HOUSE            None                 4.0        464.0
# 43                 HOUSE            None                 3.0        125.0
# 44                 HOUSE            None                 4.0        163.0
# 45           HOUSE_GROUP            None                 NaN          NaN
# 46           HOUSE_GROUP            None                 NaN          NaN
# 47           HOUSE_GROUP            None                 NaN          NaN
# 48           HOUSE_GROUP            None                 NaN          NaN
# 49           HOUSE_GROUP            None                 NaN          NaN
# 50           HOUSE_GROUP            None                 NaN          NaN
# 51                 HOUSE            None                 2.0         65.0
# 52                 HOUSE            None                 3.0        164.0
# 53                 HOUSE            None                 4.0        350.0
# 54    MIXED_USE_BUILDING            None                 4.0        350.0
# 55                 VILLA            None                 5.0        368.0
# 56                 HOUSE            None                 2.0         86.0
# 57    MIXED_USE_BUILDING            None                 4.0        247.0
# 58                 HOUSE            None                 4.0        148.0
# 59                 HOUSE            None                 3.0        129.0
#
#    sale_annuity Type_of_sale  ... hasTerrace terraceSurface  hasGarden  \
# 0          None     FOR_SALE  ...       None            NaN       None
# 1          None     FOR_SALE  ...       True           34.0       True
# 2          None     FOR_SALE  ...       True           30.0       True
# 3          None     FOR_SALE  ...       True            NaN       None
# 4          None     FOR_SALE  ...       None            NaN       None
# 5          None     FOR_SALE  ...       None            NaN       None
# 6          None     FOR_SALE  ...       True            NaN       None
# 7          None     FOR_SALE  ...       True           90.0       True
# 8          None     FOR_SALE  ...       True           20.0       True
# 9          None     FOR_SALE  ...       True            NaN       True
# 10         None     FOR_SALE  ...       True          120.0       True
# 11         None     FOR_SALE  ...       None            NaN       None
# 12         None     FOR_SALE  ...       None            NaN       None
# 13         None     FOR_SALE  ...       None            NaN       None
# 14         None     FOR_SALE  ...       None            NaN       None
# 15         None     FOR_SALE  ...       None            NaN       None
# 16         None     FOR_SALE  ...       None            NaN       None
# 17         None     FOR_SALE  ...       True            NaN       True
# 18         None     FOR_SALE  ...       True            NaN       True
# 19         None     FOR_SALE  ...       True            NaN       True
# 20         None     FOR_SALE  ...       True            NaN       True
# 21         None     FOR_SALE  ...       True           46.0       True
# 22         None     FOR_SALE  ...       True           40.0       True
# 23         None     FOR_SALE  ...       None            NaN       True
# 24         None     FOR_SALE  ...       None            NaN       True
# 25         None     FOR_SALE  ...       None            NaN       True
# 26         None     FOR_SALE  ...       True            NaN       True
# 27         None     FOR_SALE  ...       None            NaN       True
# 28         None     FOR_SALE  ...       True            NaN       True
# 29         None     FOR_SALE  ...       True            NaN       True
# 30         None     FOR_SALE  ...       True            NaN       True
# 31         None     FOR_SALE  ...       None            NaN       None
# 32         None     FOR_SALE  ...       None            NaN       None
# 33         None     FOR_SALE  ...       None            NaN       None
# 34         None     FOR_SALE  ...       None            NaN       None
# 35         None     FOR_SALE  ...       None            NaN       None
# 36         None     FOR_SALE  ...       True            NaN       None
# 37         None     FOR_SALE  ...       None            NaN       True
# 38         None     FOR_SALE  ...       True           30.0       True
# 39         None     FOR_SALE  ...       True           41.0       True
# 40         None     FOR_SALE  ...       None            NaN       True
# 41         None     FOR_SALE  ...       True            6.0       True
# 42         None     FOR_SALE  ...       True           28.0       True
# 43         None     FOR_SALE  ...       True            NaN       True
# 44         None     FOR_SALE  ...       True           10.0       True
# 45         None     FOR_SALE  ...       None            NaN       None
# 46         None     FOR_SALE  ...       None            NaN       None
# 47         None     FOR_SALE  ...       None            NaN       None
# 48         None     FOR_SALE  ...       None            NaN       None
# 49         None     FOR_SALE  ...       None            NaN       None
# 50         None     FOR_SALE  ...       None            NaN       None
# 51         None     FOR_SALE  ...       True            5.0       None
# 52         None     FOR_SALE  ...       True           21.0       True
# 53         None     FOR_SALE  ...       True           40.0       True
# 54         None     FOR_SALE  ...       True           40.0       True
# 55         None     FOR_SALE  ...       True            NaN       True
# 56         None     FOR_SALE  ...       True            NaN       None
# 57         None     FOR_SALE  ...       True           53.0       None
# 58         None     FOR_SALE  ...       None            NaN       True
# 59         None     FOR_SALE  ...       True            NaN       None
#
#     gardenSurface        Kitchen_type Number_of_facades State_of_building  \
# 0             NaN                None               NaN              None
# 1            12.0      HYPER_EQUIPPED               2.0            AS_NEW
# 2            60.0       NOT_INSTALLED               2.0       TO_RENOVATE
# 3             NaN      HYPER_EQUIPPED               3.0    JUST_RENOVATED
# 4             NaN                None               NaN              None
# 5             NaN                None               NaN              None
# 6             NaN           INSTALLED               4.0              GOOD
# 7           250.0  USA_HYPER_EQUIPPED               2.0            AS_NEW
# 8           107.0       SEMI_EQUIPPED               2.0              GOOD
# 9           372.0           INSTALLED               4.0              GOOD
# 10          250.0       NOT_INSTALLED               4.0              GOOD
# 11            NaN                None               NaN              None
# 12            NaN                None               NaN              None
# 13            NaN                None               NaN              None
# 14            NaN                None               NaN              None
# 15            NaN                None               NaN              None
# 16            NaN                None               NaN              None
# 17          222.0           INSTALLED               3.0            AS_NEW
# 18          605.0           INSTALLED               4.0              GOOD
# 19          354.0           INSTALLED               3.0            AS_NEW
# 20         1564.0       SEMI_EQUIPPED               4.0            AS_NEW
# 21         2635.0   USA_SEMI_EQUIPPED               4.0            AS_NEW
# 22         1292.0       SEMI_EQUIPPED               4.0     TO_BE_DONE_UP
# 23           24.0           INSTALLED               2.0              GOOD
# 24           24.0           INSTALLED               2.0              GOOD
# 25           24.0           INSTALLED               2.0              GOOD
# 26          900.0           INSTALLED               2.0              GOOD
# 27           11.0       NOT_INSTALLED               2.0       TO_RENOVATE
# 28          533.0           INSTALLED               2.0            AS_NEW
# 29         1332.0       SEMI_EQUIPPED               4.0              GOOD
# 30         5102.0      HYPER_EQUIPPED               4.0            AS_NEW
# 31            NaN                None               NaN              None
# 32            NaN                None               NaN              None
# 33            NaN                None               NaN              None
# 34            NaN                None               NaN              None
# 35            NaN                None               NaN              None
# 36            NaN           INSTALLED               3.0              GOOD
# 37           65.0                None               2.0            AS_NEW
# 38           20.0           INSTALLED               NaN    JUST_RENOVATED
# 39         2300.0      HYPER_EQUIPPED               4.0              GOOD
# 40          228.0           INSTALLED               3.0              GOOD
# 41           97.0       SEMI_EQUIPPED               2.0     TO_BE_DONE_UP
# 42         4350.0           INSTALLED               4.0              GOOD
# 43          370.0                None               4.0       TO_RENOVATE
# 44          120.0           INSTALLED               2.0    JUST_RENOVATED
# 45            NaN                None               NaN              None
# 46            NaN                None               NaN              None
# 47            NaN                None               NaN              None
# 48            NaN                None               NaN              None
# 49            NaN                None               NaN              None
# 50            NaN                None               NaN              None
# 51            NaN           INSTALLED               2.0              GOOD
# 52           63.0           INSTALLED               2.0              GOOD
# 53           32.0           INSTALLED               3.0              GOOD
# 54           32.0           INSTALLED               3.0              GOOD
# 55         1143.0      HYPER_EQUIPPED               4.0            AS_NEW
# 56            NaN           INSTALLED               2.0              GOOD
# 57            NaN       SEMI_EQUIPPED               3.0              GOOD
# 58          421.0                None               4.0       TO_RENOVATE
# 59            NaN       SEMI_EQUIPPED               4.0       TO_RENOVATE
#
#     Furnished Starting_price   epc
# 0        None           None  None
# 1       False           None     F
# 2       False           None     F
# 3        None           None     D
# 4        None           None  None
# 5        None           None  None
# 6        None           None     C
# 7       False          False     D
# 8        None           None     C
# 9        None           None     F
# 10      False           None     D
# 11       None           None  None
# 12       None           None  None
# 13       None           None     A
# 14       None           None     A
# 15       None           None  None
# 16       None           None  None
# 17       None           None     C
# 18       None           None     E
# 19       None           None     C
# 20       None           None     E
# 21       None           None     C
# 22       None           None     C
# 23       None           None     D
# 24       None           None     D
# 25       None           None     D
# 26       None           None     F
# 27       None           None     E
# 28       None           None     B
# 29       None           None     E
# 30       None           None     C
# 31       None           None  None
# 32       None           None  None
# 33       None           None  None
# 34       None           None  None
# 35       None           None  None
# 36       None           None     B
# 37       None           None     C
# 38       None           None     B
# 39      False           None     C
# 40       None           None     D
# 41       None           None     C
# 42       None           None     D
# 43       None           None     F
# 44       None           None     D
# 45       None           None     A
# 46       None           None  None
# 47       None           None  None
# 48       None           None  None
# 49       None           None  None
# 50       None           None  None
# 51       None          False     D
# 52       None           None     C
# 53       None           None     C
# 54       None           None     C
# 55       None           None     B
# 56       None           None     F
# 57       None           None     F
# 58       None           None     F
# 59       None           None     G
#
# [60 rows x 26 columns]
# Merged data saved to C:\Users\Rik\Desktop\immoeliza\scraper\immo_scraper_merged_land.csv

# %%
#Showing the first 50 rows of the merged dataframe
merged_df.head(50)
# Out:
#           id             locality_name Postal_code      Price  \
# 0   20264804                  Wetteren        9230        NaN
# 1   20260393                Schaerbeek        1030   495000.0
# 2   20260850       Woluwe-Saint-Pierre        1150   575000.0
# 3   20254029        SINT-PIETERS-LEEUW        1600   449000.0
# 4   20262954  Geraardsbergen Ophasselt        9500        NaN
# 5   20264095            Oostnieuwkerke        8840        NaN
# 6   20264349                 HARELBEKE        8530   379000.0
# 7   20263033                   Ixelles        1050  1995000.0
# 8   20257839                   Bertrix        6880   175000.0
# 9   20257844    Habay (Habay-la-Neuve)        6720   425000.0
# 10  20264924           Wezembeek-Oppem        1970   695000.0
# 11  20260710                     Ronse        9600        NaN
# 12  20260196                Oudsbergen        3670        NaN
# 13  20261055                   Beersel        1650        NaN
# 14  20261307                  Machelen        1830        NaN
# 15  20261469                      Gent        9000        NaN
# 16  20261471                Zwijnaarde        9052        NaN
# 17  20257815          Chiny (Jamoigne)        6810   320000.0
# 18  20257810         Libin (Transinne)        6890   349000.0
# 19  20257825    Habay (Habay-la-Neuve)        6720   420000.0
# 20  20257841           Arlon (Bonnert)        6700   560000.0
# 21  20257813          Etalle (Buzenol)        6740   640000.0
# 22  20254967                  WETTEREN        9230   740000.0
# 23  20260391                    DEURNE        2100   379000.0
# 24  20260384                    DEURNE        2100   379000.0
# 25  20260385                    DEURNE        2100   379000.0
# 26  20257843          Étalle (Buzenol)        6740   295000.0
# 27  20258423                 ANTWERPEN        2140   379900.0
# 28  20257820                    Étalle        6740   420000.0
# 29  20257826           Arlon (Heinsch)        6700   435000.0
# 30  20257819            Habay (Rulles)        6720   495000.0
# 31  20257520                 Roeselare        8800        NaN
# 32  20258833                  Nazareth        9810        NaN
# 33  20258529               Sint-Amands        2890        NaN
# 34  20257646                    Lierde        9570        NaN
# 35  20258797                  De Pinte        9840        NaN
# 36  20263841               SINT-DENIJS        8554   534000.0
# 37  20264881                   HOBOKEN        2660   314000.0
# 38  20264949                WILLEBROEK        2830   398000.0
# 39  20264801                 Vloesberg        7880   605250.0
# 40  20241535               ZWIJNDRECHT        2070   424000.0
# 41  20261092                    DEURNE        2100   642000.0
# 42  20259139             BOORTMEERBEEK        3190   896000.0
# 43  20252354                     RONSE        9600   319000.0
# 44  20258341                  MECHELEN        2800   389000.0
# 45  20257954                     THIEU        7070        NaN
# 46  20258498     Langemark-Poelkapelle        8920        NaN
# 47  20256079   Geraardsbergen Moerbeke        9500        NaN
# 48  20255074              Leopoldsburg        3970        NaN
# 49  20256142             Deinze Astene        9800        NaN
#
#                  Subtype Number_of_rooms  Number_of_bedrooms  Living_area  \
# 0            HOUSE_GROUP            None                 NaN          NaN
# 1                  HOUSE            None                 3.0        120.0
# 2                  HOUSE            None                 5.0        177.0
# 3                  HOUSE            None                 2.0        121.0
# 4            HOUSE_GROUP            None                 NaN          NaN
# 5            HOUSE_GROUP            None                 NaN          NaN
# 6                  VILLA            None                 3.0        175.0
# 7                  HOUSE            None                 4.0        544.0
# 8                  HOUSE            None                 3.0         85.0
# 9                  HOUSE            None                 2.0        128.0
# 10                 HOUSE            None                 4.0        185.0
# 11           HOUSE_GROUP            None                 NaN          NaN
# 12           HOUSE_GROUP            None                 NaN          NaN
# 13           HOUSE_GROUP            None                 NaN          NaN
# 14           HOUSE_GROUP            None                 NaN          NaN
# 15           HOUSE_GROUP            None                 NaN          NaN
# 16           HOUSE_GROUP            None                 NaN          NaN
# 17                 HOUSE            None                 4.0        197.0
# 18  EXCEPTIONAL_PROPERTY            None                 2.0        232.0
# 19                 HOUSE            None                 4.0        180.0
# 20                 VILLA            None                 3.0        119.0
# 21  EXCEPTIONAL_PROPERTY            None                 5.0        248.0
# 22                 HOUSE            None                 4.0        252.0
# 23            TOWN_HOUSE            None                 4.0        186.0
# 24                 HOUSE            None                 4.0        186.0
# 25  EXCEPTIONAL_PROPERTY            None                 4.0        186.0
# 26                 HOUSE            None                 3.0        110.0
# 27       APARTMENT_BLOCK            None                 3.0        156.0
# 28                 HOUSE            None                 3.0        128.0
# 29                 HOUSE            None                 4.0        174.0
# 30  EXCEPTIONAL_PROPERTY            None                 3.0        143.0
# 31           HOUSE_GROUP            None                 NaN          NaN
# 32           HOUSE_GROUP            None                 NaN          NaN
# 33           HOUSE_GROUP            None                 NaN          NaN
# 34           HOUSE_GROUP            None                 NaN          NaN
# 35           HOUSE_GROUP            None                 NaN          NaN
# 36       COUNTRY_COTTAGE            None                 2.0        170.0
# 37                 HOUSE            None                 4.0        132.0
# 38                 HOUSE            None                 3.0        135.0
# 39                 HOUSE            None                 3.0        300.0
# 40                 HOUSE            None                 4.0        215.0
# 41    MIXED_USE_BUILDING            None                 9.0        267.0
# 42                 HOUSE            None                 4.0        464.0
# 43                 HOUSE            None                 3.0        125.0
# 44                 HOUSE            None                 4.0        163.0
# 45           HOUSE_GROUP            None                 NaN          NaN
# 46           HOUSE_GROUP            None                 NaN          NaN
# 47           HOUSE_GROUP            None                 NaN          NaN
# 48           HOUSE_GROUP            None                 NaN          NaN
# 49           HOUSE_GROUP            None                 NaN          NaN
#
#    sale_annuity Type_of_sale  ... hasTerrace terraceSurface  hasGarden  \
# 0          None     FOR_SALE  ...       None            NaN       None
# 1          None     FOR_SALE  ...       True           34.0       True
# 2          None     FOR_SALE  ...       True           30.0       True
# 3          None     FOR_SALE  ...       True            NaN       None
# 4          None     FOR_SALE  ...       None            NaN       None
# 5          None     FOR_SALE  ...       None            NaN       None
# 6          None     FOR_SALE  ...       True            NaN       None
# 7          None     FOR_SALE  ...       True           90.0       True
# 8          None     FOR_SALE  ...       True           20.0       True
# 9          None     FOR_SALE  ...       True            NaN       True
# 10         None     FOR_SALE  ...       True          120.0       True
# 11         None     FOR_SALE  ...       None            NaN       None
# 12         None     FOR_SALE  ...       None            NaN       None
# 13         None     FOR_SALE  ...       None            NaN       None
# 14         None     FOR_SALE  ...       None            NaN       None
# 15         None     FOR_SALE  ...       None            NaN       None
# 16         None     FOR_SALE  ...       None            NaN       None
# 17         None     FOR_SALE  ...       True            NaN       True
# 18         None     FOR_SALE  ...       True            NaN       True
# 19         None     FOR_SALE  ...       True            NaN       True
# 20         None     FOR_SALE  ...       True            NaN       True
# 21         None     FOR_SALE  ...       True           46.0       True
# 22         None     FOR_SALE  ...       True           40.0       True
# 23         None     FOR_SALE  ...       None            NaN       True
# 24         None     FOR_SALE  ...       None            NaN       True
# 25         None     FOR_SALE  ...       None            NaN       True
# 26         None     FOR_SALE  ...       True            NaN       True
# 27         None     FOR_SALE  ...       None            NaN       True
# 28         None     FOR_SALE  ...       True            NaN       True
# 29         None     FOR_SALE  ...       True            NaN       True
# 30         None     FOR_SALE  ...       True            NaN       True
# 31         None     FOR_SALE  ...       None            NaN       None
# 32         None     FOR_SALE  ...       None            NaN       None
# 33         None     FOR_SALE  ...       None            NaN       None
# 34         None     FOR_SALE  ...       None            NaN       None
# 35         None     FOR_SALE  ...       None            NaN       None
# 36         None     FOR_SALE  ...       True            NaN       None
# 37         None     FOR_SALE  ...       None            NaN       True
# 38         None     FOR_SALE  ...       True           30.0       True
# 39         None     FOR_SALE  ...       True           41.0       True
# 40         None     FOR_SALE  ...       None            NaN       True
# 41         None     FOR_SALE  ...       True            6.0       True
# 42         None     FOR_SALE  ...       True           28.0       True
# 43         None     FOR_SALE  ...       True            NaN       True
# 44         None     FOR_SALE  ...       True           10.0       True
# 45         None     FOR_SALE  ...       None            NaN       None
# 46         None     FOR_SALE  ...       None            NaN       None
# 47         None     FOR_SALE  ...       None            NaN       None
# 48         None     FOR_SALE  ...       None            NaN       None
# 49         None     FOR_SALE  ...       None            NaN       None
#
#     gardenSurface        Kitchen_type Number_of_facades State_of_building  \
# 0             NaN                None               NaN              None
# 1            12.0      HYPER_EQUIPPED               2.0            AS_NEW
# 2            60.0       NOT_INSTALLED               2.0       TO_RENOVATE
# 3             NaN      HYPER_EQUIPPED               3.0    JUST_RENOVATED
# 4             NaN                None               NaN              None
# 5             NaN                None               NaN              None
# 6             NaN           INSTALLED               4.0              GOOD
# 7           250.0  USA_HYPER_EQUIPPED               2.0            AS_NEW
# 8           107.0       SEMI_EQUIPPED               2.0              GOOD
# 9           372.0           INSTALLED               4.0              GOOD
# 10          250.0       NOT_INSTALLED               4.0              GOOD
# 11            NaN                None               NaN              None
# 12            NaN                None               NaN              None
# 13            NaN                None               NaN              None
# 14            NaN                None               NaN              None
# 15            NaN                None               NaN              None
# 16            NaN                None               NaN              None
# 17          222.0           INSTALLED               3.0            AS_NEW
# 18          605.0           INSTALLED               4.0              GOOD
# 19          354.0           INSTALLED               3.0            AS_NEW
# 20         1564.0       SEMI_EQUIPPED               4.0            AS_NEW
# 21         2635.0   USA_SEMI_EQUIPPED               4.0            AS_NEW
# 22         1292.0       SEMI_EQUIPPED               4.0     TO_BE_DONE_UP
# 23           24.0           INSTALLED               2.0              GOOD
# 24           24.0           INSTALLED               2.0              GOOD
# 25           24.0           INSTALLED               2.0              GOOD
# 26          900.0           INSTALLED               2.0              GOOD
# 27           11.0       NOT_INSTALLED               2.0       TO_RENOVATE
# 28          533.0           INSTALLED               2.0            AS_NEW
# 29         1332.0       SEMI_EQUIPPED               4.0              GOOD
# 30         5102.0      HYPER_EQUIPPED               4.0            AS_NEW
# 31            NaN                None               NaN              None
# 32            NaN                None               NaN              None
# 33            NaN                None               NaN              None
# 34            NaN                None               NaN              None
# 35            NaN                None               NaN              None
# 36            NaN           INSTALLED               3.0              GOOD
# 37           65.0                None               2.0            AS_NEW
# 38           20.0           INSTALLED               NaN    JUST_RENOVATED
# 39         2300.0      HYPER_EQUIPPED               4.0              GOOD
# 40          228.0           INSTALLED               3.0              GOOD
# 41           97.0       SEMI_EQUIPPED               2.0     TO_BE_DONE_UP
# 42         4350.0           INSTALLED               4.0              GOOD
# 43          370.0                None               4.0       TO_RENOVATE
# 44          120.0           INSTALLED               2.0    JUST_RENOVATED
# 45            NaN                None               NaN              None
# 46            NaN                None               NaN              None
# 47            NaN                None               NaN              None
# 48            NaN                None               NaN              None
# 49            NaN                None               NaN              None
#
#     Furnished Starting_price   epc
# 0        None           None  None
# 1       False           None     F
# 2       False           None     F
# 3        None           None     D
# 4        None           None  None
# 5        None           None  None
# 6        None           None     C
# 7       False          False     D
# 8        None           None     C
# 9        None           None     F
# 10      False           None     D
# 11       None           None  None
# 12       None           None  None
# 13       None           None     A
# 14       None           None     A
# 15       None           None  None
# 16       None           None  None
# 17       None           None     C
# 18       None           None     E
# 19       None           None     C
# 20       None           None     E
# 21       None           None     C
# 22       None           None     C
# 23       None           None     D
# 24       None           None     D
# 25       None           None     D
# 26       None           None     F
# 27       None           None     E
# 28       None           None     B
# 29       None           None     E
# 30       None           None     C
# 31       None           None  None
# 32       None           None  None
# 33       None           None  None
# 34       None           None  None
# 35       None           None  None
# 36       None           None     B
# 37       None           None     C
# 38       None           None     B
# 39      False           None     C
# 40       None           None     D
# 41       None           None     C
# 42       None           None     D
# 43       None           None     F
# 44       None           None     D
# 45       None           None     A
# 46       None           None  None
# 47       None           None  None
# 48       None           None  None
# 49       None           None  None
#
# [50 rows x 26 columns]

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  60 non-null     int64
#  1   locality_name       60 non-null     object
#  2   Postal_code         60 non-null     object
#  3   Price               40 non-null     float64
#  4   Subtype             60 non-null     object
#  5   Number_of_rooms     0 non-null      object
#  6   Number_of_bedrooms  40 non-null     float64
#  7   Living_area         40 non-null     float64
#  8   sale_annuity        0 non-null      object
#  9   Type_of_sale        60 non-null     object
#  10  street              59 non-null     object
#  11  number              54 non-null     object
#  12  latitude            59 non-null     float64
#  13  longitude           59 non-null     float64
#  14  Open_fire           60 non-null     bool
#  15  Swimming_Pool       7 non-null      object
#  16  hasTerrace          33 non-null     object
#  17  terraceSurface      17 non-null     float64
#  18  hasGarden           33 non-null     object
#  19  gardenSurface       33 non-null     float64
#  20  Kitchen_type        37 non-null     object
#  21  Number_of_facades   39 non-null     float64
#  22  State_of_building   40 non-null     object
#  23  Furnished           5 non-null      object
#  24  Starting_price      2 non-null      object
#  25  epc                 43 non-null     object
# dtypes: bool(1), float64(8), int64(1), object(16)
# memory usage: 11.9+ KB
