# %% [markdown]
# **Picking the data (columns) for the models**

# %%
# Importing required packages and modules
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
from sklearn.preprocessing import OrdinalEncoder

# %%
# Set options to show all columns
pd.set_option('display.max_columns', None)

# Load .pkl file and generate pandas dataframe
input_pkl = r'..\data\clean\after_step_3b_outliers_cat.pkl' # Fill your path to file
df_1 = pd.read_pickle(input_pkl)

df_1_shape = df_1.shape # Pass the shape of the dataframe to a variable for summary at end of the outlier detection and removal part
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4180 entries, 0 to 5923
# Data columns (total 36 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         4180 non-null   Int64
#  1   locality_name              4180 non-null   category
#  2   Postal_code                4180 non-null   object
#  3   Price                      4180 non-null   Int64
#  4   Subtype                    4180 non-null   object
#  5   Number_of_bedrooms         4180 non-null   Int64
#  6   Living_area                4180 non-null   Int64
#  7   street                     4180 non-null   category
#  8   number                     4165 non-null   category
#  9   latitude                   4180 non-null   float64
#  10  longitude                  4180 non-null   float64
#  11  Open_fire                  4180 non-null   bool
#  12  Swimming_Pool              4180 non-null   bool
#  13  hasTerrace                 2813 non-null   object
#  14  terraceSurface             4180 non-null   Int64
#  15  gardenSurface              4180 non-null   Int64
#  16  Kitchen_type               4180 non-null   object
#  17  Number_of_facades          4180 non-null   Int64
#  18  State_of_building          4180 non-null   object
#  19  Furnished                  4180 non-null   bool
#  20  epc                        4180 non-null   object
#  21  landSurface                4180 non-null   Int64
#  22  price_per_sqm              4180 non-null   float64
#  23  price_per_sqm_land         4180 non-null   float64
#  24  Province                   4180 non-null   category
#  25  Assigned_City              1098 non-null   object
#  26  Has_Assigned_City          4180 non-null   bool
#  27  Assigned_City_5            425 non-null    object
#  28  Has_Assigned_City_5        4180 non-null   bool
#  29  Assigned_City_10           1726 non-null   object
#  30  Has_Assigned_City_10       4180 non-null   bool
#  31  Assigned_City_15           3034 non-null   object
#  32  Has_Assigned_City_15       4180 non-null   bool
#  33  Kitchen_type_encoded       4180 non-null   int64
#  34  State_of_building_encoded  4180 non-null   int64
#  35  EPC_encoded                4180 non-null   int64
# dtypes: Int64(8), bool(7), category(4), float64(4), int64(3), object(10)
# memory usage: 996.2+ KB

# %% [markdown]
# **This selection is made based on the correlation matrix in Team_6_Step_4**

# %%
selected_columns = ['Price','Number_of_bedrooms','Living_area','Number_of_facades','State_of_building','epc','landSurface','Has_Assigned_City','Province'] 
df = df_1[selected_columns].copy(deep=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4180 entries, 0 to 5923
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Price               4180 non-null   Int64
#  1   Number_of_bedrooms  4180 non-null   Int64
#  2   Living_area         4180 non-null   Int64
#  3   Number_of_facades   4180 non-null   Int64
#  4   State_of_building   4180 non-null   object
#  5   epc                 4180 non-null   object
#  6   landSurface         4180 non-null   Int64
#  7   Has_Assigned_City   4180 non-null   bool
#  8   Province            4180 non-null   category
# dtypes: Int64(5), bool(1), category(1), object(2)
# memory usage: 289.9+ KB

# %%
df.head(30)
# Out:
#      Price  Number_of_bedrooms  Living_area  Number_of_facades  \
# 0   319000                   3          125                  4
# 1   299999                   3          167                  2
# 2   275000                   3          154                  2
# 3   295000                   3          172                  3
# 5   715000                   3          280                  3
# 7   198800                   3          125                  2
# 8   299000                   3          132                  2
# 9   469000                   3          153                  4
# 11  284000                   3          148                  2
# 12  339000                   3          164                  3
# 13  349000                   3          193                  2
# 15  284000                   3           89                  2
# 17  160000                   4          147                  2
# 18  348500                   3          125                  3
# 19  409000                   2          160                  3
# 21  345000                   3          223                  2
# 23  384950                   3          160                  2
# 26  319000                   4          188                  2
# 28  315000                   3          194                  2
# 29  319000                   3          117                  3
# 30  329000                   4          198                  4
# 31  345000                   3          151                  3
# 32  379000                   3          182                  4
# 33  815000                   5          270                  3
# 35  455000                   3          147                  3
# 38  298000                   4          242                  2
# 41  375000                   3          149                  3
# 46  369000                   4          144                  3
# 48  132000                   2           76                  2
# 49  178000                   3          171                  2
#
#    State_of_building epc  landSurface  Has_Assigned_City         Province
# 0        To renovate   F          767              False    East Flanders
# 1               Good   D         1050              False    East Flanders
# 2        To renovate   E          120              False          Antwerp
# 3        To renovate   F          309              False   Brabant_Wallon
# 5             As new   C          374              False   Brabant_Wallon
# 7        To renovate   F          250              False    East Flanders
# 8             As new   D          145               True          Antwerp
# 9        To renovate   D          412              False          Antwerp
# 11              Good   C          119              False          Antwerp
# 12              Good   A          108              False    West Flanders
# 13     To be done up   D          135               True          Antwerp
# 15     To be done up   E          233               True          Antwerp
# 17     To be done up   C          140              False    East Flanders
# 18              Good   D          670              False            Liège
# 19     To be done up   F          757               True  Flemish Brabant
# 21            As new   C          180              False    West Flanders
# 23     To be done up   D          170               True          Antwerp
# 26              Good   F          816              False            Namur
# 28       To renovate   E          150              False  Flemish Brabant
# 29              Good   E          381              False    East Flanders
# 30              Good   D         1055              False    West Flanders
# 31              Good   B          112              False    East Flanders
# 32              Good   D          724              False    East Flanders
# 33            As new   D          335              False         Brussels
# 35    Just renovated   A          217              False    East Flanders
# 38              Good   F          358              False            Liège
# 41              Good   D          361               True    East Flanders
# 46            As new   C          150               True    West Flanders
# 48       To renovate   F          190               True            Liège
# 49       To renovate   F          681              False    West Flanders

# %% [markdown]
# **Checking for missing values**

# %%
df.isnull().sum()
# Out:
# Price                 0
# Number_of_bedrooms    0
# Living_area           0
# Number_of_facades     0
# State_of_building     0
# epc                   0
# landSurface           0
# Has_Assigned_City     0
# Province              0
# dtype: int64

# %% [markdown]
# **Dealing with categorical Features**

# %%
categorical_df = df.select_dtypes(include=['category','object'])

categorical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4180 entries, 0 to 5923
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   State_of_building  4180 non-null   object
#  1   epc                4180 non-null   object
#  2   Province           4180 non-null   category
# dtypes: category(1), object(2)
# memory usage: 102.1+ KB

# %% [markdown]
# **Encoding Province** - get_dummies

# %%
province_dummies= pd.get_dummies(categorical_df['Province'], drop_first=True)
province_dummies.head()
# Out:
#    Brabant_Wallon  Brussels  East Flanders  Flemish Brabant  Hainaut  Limburg  \
# 0           False     False           True            False    False    False
# 1           False     False           True            False    False    False
# 2           False     False          False            False    False    False
# 3            True     False          False            False    False    False
# 5            True     False          False            False    False    False
#
#    Liège  Luxembourg  Namur  West Flanders
# 0  False       False  False          False
# 1  False       False  False          False
# 2  False       False  False          False
# 3  False       False  False          False
# 5  False       False  False          False

# %%
df = pd.concat([df,province_dummies], axis=1)
df= df.drop('Province', axis=1)

# %% [markdown]
# **Encoding EPC** - Ordinalencoder

# %%
categorical_df['epc'].value_counts()
# Out:
# epc
# F    970
# C    920
# D    743
# B    619
# E    484
# A    444
# Name: count, dtype: int64

# %%
list_epc = categorical_df['epc'].values.tolist()
unique_epc = list(set(list_epc))
unique_epc.sort(reverse=True)

# %%
print(unique_epc)
# Out:
# ['F', 'E', 'D', 'C', 'B', 'A']

# %%
epc_val = categorical_df[['epc']].values

# %%
encoder = OrdinalEncoder(categories=[unique_epc])

# %%
#encode and add to the main df
df['Encoded_epc'] = encoder.fit_transform(epc_val)
df= df.drop('epc', axis=1)

# %% [markdown]
# ***Encoding State_of_building*** - Ordinalencoder

# %%
categorical_df['State_of_building'].value_counts()
# Out:
# State_of_building
# Good              2044
# To renovate        755
# As new             723
# To be done up      444
# Just renovated     214
# Name: count, dtype: int64

# %%
list_state = categorical_df['State_of_building'].values.tolist()
unique_state = list(set(list_state))
print(unique_state)
# Out:
# ['To renovate', 'Just renovated', 'As new', 'Good', 'To be done up']

# %%
sort_unique_state = ['To renovate','To be done up','Good', 'Just renovated','As new']

# %%
state_val = categorical_df[['State_of_building']].values

# %%
encoder = OrdinalEncoder(categories=[sort_unique_state])

# %%
df['Encoded_state_of_building'] = encoder.fit_transform(state_val)
df= df.drop('State_of_building', axis=1)

# %% [markdown]
# **CENTRING AND SCALING**

# %%
# Save data to new csv file

output_csv = r'..\data\clean\model_training.csv'  # Fill your path to file
df.to_csv(output_csv, index=False)


# Save data to new pkl file


output_pkl = r'..\data\clean\model_training.pkl' # Fill your path to file
with open(output_pkl, 'wb') as f:
    pickle.dump(df, f)
